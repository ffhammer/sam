# %%
from data_formats import read_data
from dose_reponse_fit import dose_response_fit, StandardSettings
import matplotlib.pyplot as plt
from plotting import *
from stress_survival_conversion import stress_to_survival, survival_to_stress
import random
import glob
from tqdm import tqdm
import pandas as pd
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
df = pd.read_csv("better.csv")

x = df.right_borders.values[:, None]
y = np.cumsum(df.probs).values
plt.plot(x,y)
plt.show()

# %%
pysr_model = PySRRegressor(
    binary_operators=["+", "-", "*", "/"],
    unary_operators=["exp", "log", "tanh", "sqrt", "inv(x) = 1/x"],
    extra_sympy_mappings={"inv": lambda x: 1/x},
    niterations=100,  # Adjust depending on the complexity of your function
    populations=50,   # More populations to better explore the equation space
    progress=True,     # Display progress bar
    random_state = False,
)

x = df.right_borders.values[:, None]
y = np.cumsum(df.probs).values


pysr_model.fit(x, y)
# Out:
# [ Info: Started!
# Expressions evaluated per second: 2.100e+04
# Head worker occupation: 9.7%
# Progress: 47 / 5000 total iterations (0.940%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.447e-02  7.971e+00  y = tanh(0.37324)
# 3           7.027e-03  7.226e-01  y = tanh(tanh(x₀))
# 4           4.389e-03  4.707e-01  y = tanh(tanh(tanh(x₀)))
# 5           8.772e-04  1.610e+00  y = tanh(sqrt(x₀ * 0.37324))
# 8           8.413e-04  1.390e-02  y = tanh(sqrt(x₀ / exp(tanh(exp(x₀)))))
# 9           7.970e-04  5.411e-02  y = tanh(sqrt(x₀ / exp(tanh(exp(sqrt(x₀))))))
# 10          7.218e-04  9.912e-02  y = sqrt(x₀) / (sqrt(exp(0.27272)) + tanh(sqrt(x₀)))
# 11          7.131e-04  1.212e-02  y = sqrt(x₀) / (sqrt(exp(0.58377)) + tanh(tanh(tanh(x₀))))
# 12          4.549e-04  4.495e-01  y = tanh(tanh(tanh(sqrt(exp(log(x₀) * (exp(x₀) + x₀))))))
# 14          3.910e-04  7.565e-02  y = tanh(exp((exp(exp(x₀ - inv(x₀))) * log(sqrt(x₀))) - 0.4207...
#                                   6))
# 16          3.347e-04  7.785e-02  y = tanh(exp((exp(exp(sqrt(sqrt(x₀)) - inv(x₀))) * log(sqrt(x₀...
#                                   ))) - 0.42076))
# 17          2.936e-04  1.310e-01  y = tanh(tanh(tanh(inv((tanh(sqrt(inv(x₀) - x₀) * 2.2122) - -0...
#                                   .40633) / sqrt(x₀)))))
# 18          2.316e-04  2.372e-01  y = tanh(tanh(tanh(inv((tanh(((inv(x₀) - x₀) * 2.2122) / 0.389...
#                                   97) - -0.40633) / sqrt(x₀)))))
# 19          2.076e-04  1.093e-01  y = inv(((inv(0.67101 * tanh(sqrt(x₀))) + (0.52204 - (x₀ * (x₀...
#                                    * x₀)))) - 0.81063) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.600e+04
# Head worker occupation: 5.3%
# Progress: 116 / 5000 total iterations (2.320%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.382e-02  7.971e+00  y = tanh(0.40213)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           4.389e-03  4.707e-01  y = tanh(tanh(tanh(x₀)))
# 5           8.772e-04  1.610e+00  y = tanh(sqrt(x₀ * 0.37324))
# 6           8.767e-04  5.387e-04  y = tanh(sqrt(x₀ / exp(0.99304)))
# 7           7.444e-04  1.636e-01  y = tanh(0.55724 * (sqrt(x₀) - -0.067368))
# 8           7.444e-04  1.562e-05  y = tanh(0.55724 * (sqrt(x₀) - tanh(-0.067368)))
# 9           6.993e-04  6.249e-02  y = tanh(x₀ / (tanh(x₀) + sqrt(tanh(x₀))))
# 10          5.888e-04  1.721e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 12          4.549e-04  1.289e-01  y = tanh(tanh(tanh(sqrt(exp(log(x₀) * (exp(x₀) + x₀))))))
# 13          4.311e-04  5.387e-02  y = tanh(tanh(sqrt(exp(exp(x₀) * log(x₀)) / (1.1026 - -0.55335...
#                                   ))))
# 14          3.910e-04  9.743e-02  y = tanh(exp((exp(exp(x₀ - inv(x₀))) * log(sqrt(x₀))) - 0.4207...
#                                   6))
# 15          3.367e-04  1.497e-01  y = tanh(exp((exp(exp(sqrt(x₀) - inv(x₀))) * log(sqrt(x₀))) - ...
#                                   0.42076))
# 16          3.347e-04  5.997e-03  y = tanh(exp((exp(exp(sqrt(sqrt(x₀)) - inv(x₀))) * log(sqrt(x₀...
#                                   ))) - 0.42076))
# 17          2.918e-04  1.370e-01  y = tanh(exp((log(sqrt(x₀)) * exp(exp(inv(0.96015) - inv(x₀)))...
#                                   ) - 0.42076) * 1.0617)
# 18          2.316e-04  2.312e-01  y = tanh(tanh(tanh(inv((tanh(((inv(x₀) - x₀) * 2.2122) / 0.389...
#                                   97) - -0.40633) / sqrt(x₀)))))
# 19          2.076e-04  1.093e-01  y = inv(((inv(0.67101 * tanh(sqrt(x₀))) + (0.52204 - (x₀ * (x₀...
#                                    * x₀)))) - 0.81063) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.530e+04
# Head worker occupation: 4.6%
# Progress: 169 / 5000 total iterations (3.380%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.382e-02  7.971e+00  y = tanh(0.40213)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           4.389e-03  4.707e-01  y = tanh(tanh(tanh(x₀)))
# 5           8.765e-04  1.611e+00  y = tanh(sqrt(x₀) / 1.6408)
# 7           7.444e-04  8.167e-02  y = tanh(0.55724 * (sqrt(x₀) - -0.067368))
# 8           7.444e-04  1.562e-05  y = tanh(0.55724 * (sqrt(x₀) - tanh(-0.067368)))
# 9           6.993e-04  6.249e-02  y = tanh(x₀ / (tanh(x₀) + sqrt(tanh(x₀))))
# 10          5.888e-04  1.721e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 11          4.528e-04  2.625e-01  y = tanh(tanh(exp((exp(x₀) * log(sqrt(x₀))) - 0.26359)))
# 12          4.054e-04  1.107e-01  y = tanh(exp((exp(x₀ * x₀) * log(sqrt(x₀))) - 0.42076))
# 14          3.420e-04  8.500e-02  y = tanh(exp((exp(exp(0.85223 - inv(x₀))) * log(sqrt(x₀))) - 0...
#                                   .42076))
# 15          2.986e-04  1.356e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(sqrt(x₀) * x₀) - 0.12089)) ...
#                                   - 0.42076))
# 16          2.983e-04  1.258e-03  y = tanh(exp((log(sqrt(x₀)) * (exp(sqrt(x₀) * x₀) - tanh(0.120...
#                                   89))) - 0.42076))
# 17          2.120e-04  3.412e-01  y = tanh(exp(((exp((x₀ * x₀) / sqrt(0.40931)) * log(sqrt(x₀)))...
#                                    - -0.044566) - 0.40931))
# 19          2.076e-04  1.055e-02  y = inv(((inv(0.67101 * tanh(sqrt(x₀))) + (0.52204 - (x₀ * (x₀...
#                                    * x₀)))) - 0.81063) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.590e+04
# Head worker occupation: 4.0%
# Progress: 234 / 5000 total iterations (4.680%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.382e-02  7.971e+00  y = tanh(0.40213)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           4.389e-03  4.707e-01  y = tanh(tanh(tanh(x₀)))
# 5           8.765e-04  1.611e+00  y = tanh(sqrt(x₀) / 1.6408)
# 7           7.444e-04  8.167e-02  y = tanh(0.55724 * (sqrt(x₀) - -0.067368))
# 8           7.444e-04  1.562e-05  y = tanh(0.55724 * (sqrt(x₀) - tanh(-0.067368)))
# 9           6.993e-04  6.249e-02  y = tanh(x₀ / (tanh(x₀) + sqrt(tanh(x₀))))
# 10          5.888e-04  1.721e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 11          4.528e-04  2.625e-01  y = tanh(tanh(exp((exp(x₀) * log(sqrt(x₀))) - 0.26359)))
# 12          4.025e-04  1.178e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - 0.42076))
# 14          3.420e-04  8.145e-02  y = tanh(exp((exp(exp(0.85223 - inv(x₀))) * log(sqrt(x₀))) - 0...
#                                   .42076))
# 15          2.795e-04  2.019e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - (sqrt(x₀) - x₀))) - 0...
#                                   .41331))
# 16          2.107e-04  2.825e-01  y = tanh(exp((exp(exp((-0.083283 + 1.3676) - inv(x₀))) * log(s...
#                                   qrt(x₀))) - 0.33176))
# 17          2.107e-04  1.546e-04  y = tanh(exp((exp(exp((tanh(-0.083283) + 1.3676) - inv(x₀))) *...
#                                    log(sqrt(x₀))) - 0.33176))
# 19          2.076e-04  7.317e-03  y = inv(((inv(0.67101 * tanh(sqrt(x₀))) + (0.52204 - (x₀ * (x₀...
#                                    * x₀)))) - 0.81063) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.870e+04
# Head worker occupation: 4.1%
# Progress: 299 / 5000 total iterations (5.980%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.382e-02  7.971e+00  y = tanh(0.40213)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           4.389e-03  4.707e-01  y = tanh(tanh(tanh(x₀)))
# 5           8.765e-04  1.611e+00  y = tanh(sqrt(x₀) / 1.6408)
# 7           7.444e-04  8.168e-02  y = tanh(0.55728 * (sqrt(x₀) - -0.067007))
# 9           6.993e-04  3.124e-02  y = tanh(x₀ / (tanh(x₀) + sqrt(tanh(x₀))))
# 10          5.888e-04  1.721e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 11          4.528e-04  2.625e-01  y = tanh(tanh(exp((exp(x₀) * log(sqrt(x₀))) - 0.26359)))
# 12          4.025e-04  1.178e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - 0.42076))
# 14          2.534e-04  2.313e-01  y = tanh(exp((exp(exp(1.3676 - inv(x₀))) * log(sqrt(x₀))) - 0....
#                                   33176))
# 16          2.107e-04  9.235e-02  y = tanh(exp((exp(exp((-0.083283 + 1.3676) - inv(x₀))) * log(s...
#                                   qrt(x₀))) - 0.33176))
# 17          2.107e-04  1.546e-04  y = tanh(exp((exp(exp((tanh(-0.083283) + 1.3676) - inv(x₀))) *...
#                                    log(sqrt(x₀))) - 0.33176))
# 19          2.076e-04  7.317e-03  y = inv(((inv(0.67101 * tanh(sqrt(x₀))) + (0.52204 - (x₀ * (x₀...
#                                    * x₀)))) - 0.81063) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.650e+04
# Head worker occupation: 3.9%
# Progress: 363 / 5000 total iterations (7.260%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.382e-02  7.971e+00  y = tanh(0.40213)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           4.389e-03  4.707e-01  y = tanh(tanh(tanh(x₀)))
# 5           8.765e-04  1.611e+00  y = tanh(sqrt(x₀) / 1.6408)
# 7           7.444e-04  8.168e-02  y = tanh(0.55728 * (sqrt(x₀) - -0.067007))
# 9           6.993e-04  3.124e-02  y = tanh(x₀ / (tanh(x₀) + sqrt(tanh(x₀))))
# 10          5.888e-04  1.721e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 11          4.528e-04  2.625e-01  y = tanh(tanh(exp((exp(x₀) * log(sqrt(x₀))) - 0.26359)))
# 12          4.025e-04  1.178e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - 0.42076))
# 13          3.506e-04  1.382e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - tanh(0.42...
#                                   076)))
# 14          2.534e-04  3.244e-01  y = tanh(exp((exp(exp(1.3676 - inv(x₀))) * log(sqrt(x₀))) - 0....
#                                   33176))
# 15          2.370e-04  6.697e-02  y = tanh(exp((exp(exp(1.295 - inv(x₀))) * log(sqrt(x₀))) - tan...
#                                   h(0.33176)))
# 16          2.107e-04  1.177e-01  y = tanh(exp((exp(exp((-0.083283 + 1.3676) - inv(x₀))) * log(s...
#                                   qrt(x₀))) - 0.33176))
# 17          2.107e-04  1.546e-04  y = tanh(exp((exp(exp((tanh(-0.083283) + 1.3676) - inv(x₀))) *...
#                                    log(sqrt(x₀))) - 0.33176))
# 18          2.105e-04  7.622e-04  y = tanh(exp(((log(sqrt(x₀)) * exp(exp(1.295 - inv(x₀)))) - ta...
#                                   nh(tanh(0.33176))) + -0.031017))
# 19          2.076e-04  1.387e-02  y = inv(((inv(0.67101 * tanh(sqrt(x₀))) + (0.52204 - (x₀ * (x₀...
#                                    * x₀)))) - 0.81063) + x₀)
# 20          2.028e-04  2.328e-02  y = tanh(exp(((log(sqrt(x₀)) * exp(exp(sqrt(sqrt(exp(x₀))) - i...
#                                   nv(x₀)))) - tanh(0.33176)) + -0.031017))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.790e+04
# Head worker occupation: 3.8%
# Progress: 427 / 5000 total iterations (8.540%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.382e-02  7.971e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           4.389e-03  4.707e-01  y = tanh(tanh(tanh(x₀)))
# 5           8.765e-04  1.611e+00  y = tanh(sqrt(x₀) / 1.6408)
# 7           7.444e-04  8.168e-02  y = tanh(0.55728 * (sqrt(x₀) - -0.067007))
# 9           6.993e-04  3.124e-02  y = tanh(x₀ / (tanh(x₀) + sqrt(tanh(x₀))))
# 10          5.888e-04  1.721e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 11          4.528e-04  2.625e-01  y = tanh(tanh(exp((exp(x₀) * log(sqrt(x₀))) - 0.26359)))
# 12          4.025e-04  1.178e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - 0.42076))
# 13          3.506e-04  1.382e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - tanh(0.42...
#                                   076)))
# 14          2.097e-04  5.138e-01  y = tanh(exp((exp(exp(1.295 - inv(x₀))) * log(sqrt(x₀))) - 0.3...
#                                   3176))
# 19          1.997e-04  9.770e-03  y = tanh(exp(((log(sqrt(x₀)) * exp(exp(sqrt(sqrt(exp(x₀))) - i...
#                                   nv(x₀)))) - 0.33176) + -0.031017))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.880e+04
# Head worker occupation: 3.5%
# Progress: 497 / 5000 total iterations (9.940%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.382e-02  7.971e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           4.389e-03  4.707e-01  y = tanh(tanh(tanh(x₀)))
# 5           8.765e-04  1.611e+00  y = tanh(sqrt(x₀) / 1.6408)
# 7           7.444e-04  8.168e-02  y = tanh(0.55728 * (sqrt(x₀) - -0.067007))
# 8           7.421e-04  3.115e-03  y = sqrt(x₀) / (0.90347 + sqrt(sqrt(x₀)))
# 9           6.664e-04  1.076e-01  y = sqrt(x₀) / (sqrt(tanh(sqrt(x₀))) - -0.96658)
# 10          5.888e-04  1.239e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 11          4.528e-04  2.625e-01  y = tanh(tanh(exp((exp(x₀) * log(sqrt(x₀))) - 0.26359)))
# 12          4.025e-04  1.178e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - 0.42076))
# 13          3.506e-04  1.382e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - tanh(0.42...
#                                   076)))
# 14          2.097e-04  5.138e-01  y = tanh(exp((exp(exp(1.295 - inv(x₀))) * log(sqrt(x₀))) - 0.3...
#                                   3176))
# 19          1.906e-04  1.909e-02  y = tanh(tanh(inv(tanh(tanh(x₀)) + (inv(tanh(sqrt(x₀) * 0.7911...
#                                   3)) - (x₀ * (x₀ * x₀))))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.970e+04
# Head worker occupation: 3.6%
# Progress: 571 / 5000 total iterations (11.420%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.382e-02  7.971e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.261e-03  1.717e+00  y = sqrt(x₀ * 0.34137)
# 5           8.765e-04  3.641e-01  y = tanh(sqrt(x₀) / 1.6408)
# 7           7.444e-04  8.168e-02  y = tanh(0.55728 * (sqrt(x₀) - -0.067007))
# 8           7.421e-04  3.115e-03  y = sqrt(x₀) / (0.90347 + sqrt(sqrt(x₀)))
# 9           6.664e-04  1.076e-01  y = sqrt(x₀) / (sqrt(tanh(sqrt(x₀))) - -0.96658)
# 10          5.888e-04  1.239e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 11          4.528e-04  2.625e-01  y = tanh(tanh(exp((exp(x₀) * log(sqrt(x₀))) - 0.26359)))
# 12          4.025e-04  1.178e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - 0.42076))
# 13          3.506e-04  1.382e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - tanh(0.42...
#                                   076)))
# 14          1.835e-04  6.474e-01  y = tanh(tanh(sqrt(x₀) / (sqrt(x₀) + sqrt(tanh(inv(x₀) - x₀)))...
#                                   ))
# 18          1.807e-04  3.779e-03  y = tanh(sqrt(x₀) / (sqrt(tanh(((inv(x₀) - x₀) / sqrt(0.14216)...
#                                   ) / 1.0366)) + sqrt(x₀)))
# 19          1.556e-04  1.496e-01  y = tanh(exp((exp(exp(1.295 / (inv(1.295 - inv(x₀)) - x₀))) * ...
#                                   log(sqrt(x₀))) - 0.33176))
# 20          1.452e-04  6.940e-02  y = tanh(exp((exp(exp(1.295 / (inv(1.295 - inv(x₀)) - x₀))) * ...
#                                   log(sqrt(x₀))) - tanh(0.33176)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.070e+04
# Head worker occupation: 3.6%
# Progress: 655 / 5000 total iterations (13.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.155e+01  1.594e+01  y = -3.0149
# 2           1.382e-02  6.728e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.055e-03  1.896e+00  y = sqrt(0.32124 * x₀)
# 5           8.765e-04  1.858e-01  y = tanh(sqrt(x₀) / 1.6408)
# 7           7.444e-04  8.168e-02  y = tanh(0.55728 * (sqrt(x₀) - -0.067007))
# 8           7.375e-04  9.257e-03  y = sqrt(x₀) / (0.89401 + sqrt(sqrt(x₀)))
# 9           6.664e-04  1.014e-01  y = sqrt(x₀) / (sqrt(tanh(sqrt(x₀))) - -0.96658)
# 10          5.888e-04  1.239e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 11          4.528e-04  2.625e-01  y = tanh(tanh(exp((exp(x₀) * log(sqrt(x₀))) - 0.26359)))
# 12          4.025e-04  1.178e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - 0.42076))
# 13          2.803e-04  3.617e-01  y = tanh(inv(tanh(inv(x₀ * x₀) - 0.44499) + inv(sqrt(x₀))))
# 14          1.414e-04  6.843e-01  y = tanh(sqrt(x₀) / (sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(x₀)...
#                                   ))
# 16          1.221e-04  7.344e-02  y = tanh(sqrt(x₀) / (sqrt(x₀) + sqrt(tanh(sqrt(inv(x₀) - x₀) /...
#                                    x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.380e+04
# Head worker occupation: 3.7%
# Progress: 743 / 5000 total iterations (14.860%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.155e+01  1.594e+01  y = -3.0149
# 2           1.382e-02  6.728e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 7           7.444e-04  8.168e-02  y = tanh(0.55728 * (sqrt(x₀) - -0.067007))
# 8           7.375e-04  9.257e-03  y = sqrt(x₀) / (0.89401 + sqrt(sqrt(x₀)))
# 9           6.664e-04  1.014e-01  y = sqrt(x₀) / (sqrt(tanh(sqrt(x₀))) - -0.96658)
# 10          5.888e-04  1.239e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 11          4.528e-04  2.625e-01  y = tanh(tanh(exp((exp(x₀) * log(sqrt(x₀))) - 0.26359)))
# 12          4.025e-04  1.178e-01  y = tanh(exp((log(sqrt(x₀)) * (exp(x₀) - 0.20698)) - 0.42076))
# 13          2.803e-04  3.617e-01  y = tanh(inv(tanh(inv(x₀ * x₀) - 0.44499) + inv(sqrt(x₀))))
# 14          1.414e-04  6.843e-01  y = tanh(sqrt(x₀) / (sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(x₀)...
#                                   ))
# 15          1.266e-04  1.106e-01  y = tanh(sqrt(x₀) / (sqrt(x₀) + tanh(sqrt(inv(x₀) - x₀) * 2.01...
#                                   63)))
# 16          1.167e-04  8.188e-02  y = tanh((sqrt(x₀) / 1.012) / (sqrt(sqrt(tanh(inv(x₀) - x₀))) ...
#                                   + sqrt(x₀)))
# 17          1.165e-04  1.707e-03  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ) + 0.013143)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.510e+04
# Head worker occupation: 3.8%
# Progress: 821 / 5000 total iterations (16.420%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.155e+01  1.594e+01  y = -3.0149
# 2           1.382e-02  6.728e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 7           7.444e-04  8.168e-02  y = tanh(0.55728 * (sqrt(x₀) - -0.067007))
# 8           7.375e-04  9.257e-03  y = sqrt(x₀) / (0.89401 + sqrt(sqrt(x₀)))
# 9           6.664e-04  1.014e-01  y = sqrt(x₀) / (sqrt(tanh(sqrt(x₀))) - -0.96658)
# 10          5.888e-04  1.239e-01  y = sqrt(x₀) / (sqrt(sqrt(x₀)) + tanh(inv(x₀)))
# 11          3.550e-04  5.060e-01  y = tanh(tanh(inv(sqrt(1.2765) + sqrt(inv(x₀) - x₀))))
# 13          2.803e-04  1.180e-01  y = tanh(inv(tanh(inv(x₀ * x₀) - 0.44499) + inv(sqrt(x₀))))
# 14          1.414e-04  6.843e-01  y = tanh(sqrt(x₀) / (sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(x₀)...
#                                   ))
# 15          1.184e-04  1.780e-01  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ))))
# 16          1.167e-04  1.454e-02  y = tanh((sqrt(x₀) / 1.012) / (sqrt(sqrt(tanh(inv(x₀) - x₀))) ...
#                                   + sqrt(x₀)))
# 17          1.165e-04  1.707e-03  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ) + 0.013143)))
# 20          1.130e-04  9.985e-03  y = tanh(sqrt(x₀) / (sqrt(tanh(x₀ * sqrt(tanh(inv(x₀) - sqrt(x...
#                                   ₀))))) - inv(-0.96658))) - 0.0039736
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.530e+04
# Head worker occupation: 3.8%
# Progress: 895 / 5000 total iterations (17.900%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.155e+01  1.594e+01  y = -3.0149
# 2           1.382e-02  6.728e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           2.235e-04  3.702e-01  y = tanh(inv(1.2765 + sqrt(inv(x₀) - x₀)))
# 10          1.932e-04  1.456e-01  y = tanh(inv(1.2765 + sqrt(inv(x₀) - sqrt(x₀))))
# 11          1.333e-04  3.710e-01  y = tanh(inv(1.1466 + sqrt(inv(x₀) - (x₀ * x₀))))
# 15          1.184e-04  2.980e-02  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ))))
# 16          1.167e-04  1.454e-02  y = tanh((sqrt(x₀) / 1.012) / (sqrt(sqrt(tanh(inv(x₀) - x₀))) ...
#                                   + sqrt(x₀)))
# 17          1.165e-04  1.707e-03  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ) + 0.013143)))
# 18          1.096e-04  6.038e-02  y = tanh(((sqrt(x₀) / 1.012) / (sqrt(sqrt(tanh(inv(x₀) - x₀)))...
#                                    + sqrt(x₀))) + -0.0027852)
# 19          1.022e-04  7.055e-02  y = tanh(sqrt(x₀) / ((sqrt(x₀) / 0.92858) + tanh(sqrt(exp(0.92...
#                                   622)) * sqrt(inv(x₀) - x₀))))
# 20          9.860e-05  3.548e-02  y = tanh(sqrt(x₀) / ((sqrt(x₀) / 0.92858) + tanh(sqrt(exp(sqrt...
#                                   (x₀))) * sqrt(inv(x₀) - x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.470e+04
# Head worker occupation: 3.9%
# Progress: 972 / 5000 total iterations (19.440%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.155e+01  1.594e+01  y = -3.0149
# 2           1.382e-02  6.728e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.333e-04  9.311e-02  y = tanh(inv(1.1466 + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  2.312e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 15          1.184e-04  3.648e-02  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ))))
# 16          1.167e-04  1.454e-02  y = tanh((sqrt(x₀) / 1.012) / (sqrt(sqrt(tanh(inv(x₀) - x₀))) ...
#                                   + sqrt(x₀)))
# 17          1.135e-04  2.746e-02  y = tanh((sqrt(x₀) / (sqrt(x₀) + sqrt(sqrt(tanh(inv(x₀) - sqrt...
#                                   (x₀)))))) / 1.031)
# 18          1.096e-04  3.462e-02  y = tanh(((sqrt(x₀) / 1.012) / (sqrt(sqrt(tanh(inv(x₀) - x₀)))...
#                                    + sqrt(x₀))) + -0.0027852)
# 19          8.539e-05  2.498e-01  y = (sqrt(x₀) / (sqrt(sqrt(tanh(inv(x₀) - (x₀ * x₀)))) + sqrt(...
#                                   x₀ / 0.87582))) / 1.031
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.430e+04
# Head worker occupation: 3.8%
# Progress: 1058 / 5000 total iterations (21.160%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.155e+01  1.594e+01  y = -3.0149
# 2           1.382e-02  6.728e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.333e-04  9.311e-02  y = tanh(inv(1.1466 + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  2.312e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 14          1.259e-04  1.082e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * (x₀ * x₀))) + sqrt(1.1466)))
# 15          1.184e-04  6.214e-02  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ))))
# 16          1.160e-04  1.986e-02  y = tanh((sqrt(x₀) / (sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(x₀...
#                                   ))) + -0.0027852)
# 17          9.387e-05  2.120e-01  y = (sqrt(tanh(x₀)) / (sqrt(sqrt(tanh(inv(x₀) - sqrt(x₀)))) + ...
#                                   sqrt(x₀))) / 1.031
# 19          8.324e-05  6.008e-02  y = tanh((sqrt(x₀) / (sqrt(tanh(x₀)) + sqrt(sqrt(tanh(inv(x₀) ...
#                                   - (x₀ * x₀)))))) / 1.031)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.370e+04
# Head worker occupation: 3.9%
# Progress: 1125 / 5000 total iterations (22.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.155e+01  1.594e+01  y = -3.0149
# 2           1.382e-02  6.728e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.332e-04  9.369e-02  y = tanh(inv(1.1368 + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  2.254e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 14          1.259e-04  1.082e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * (x₀ * x₀))) + sqrt(1.1466)))
# 15          1.184e-04  6.214e-02  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ))))
# 16          1.071e-04  1.003e-01  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - sqrt(x₀))) * 1.1375) + s...
#                                   qrt(inv(x₀))))
# 17          9.387e-05  1.315e-01  y = (sqrt(tanh(x₀)) / (sqrt(sqrt(tanh(inv(x₀) - sqrt(x₀)))) + ...
#                                   sqrt(x₀))) / 1.031
# 19          7.667e-05  1.012e-01  y = (sqrt(x₀) / (sqrt(tanh(sqrt(((inv(x₀) / x₀) / x₀) - x₀))) ...
#                                   + sqrt(x₀))) / 1.0647
# 20          7.645e-05  2.839e-03  y = (sqrt(tanh(tanh(x₀))) / (sqrt(sqrt(tanh(inv(x₀) - sqrt(sqr...
#                                   t(x₀))))) + sqrt(tanh(x₀)))) / 1.031
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.400e+04
# Head worker occupation: 3.9%
# Progress: 1209 / 5000 total iterations (24.180%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.155e+01  1.594e+01  y = -3.0149
# 2           1.382e-02  6.728e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.332e-04  9.369e-02  y = tanh(inv(1.1368 + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  2.254e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 14          1.259e-04  1.082e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * (x₀ * x₀))) + sqrt(1.1466)))
# 15          1.184e-04  6.214e-02  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ))))
# 16          1.071e-04  1.003e-01  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - sqrt(x₀))) * 1.1375) + s...
#                                   qrt(inv(x₀))))
# 17          9.387e-05  1.315e-01  y = (sqrt(tanh(x₀)) / (sqrt(sqrt(tanh(inv(x₀) - sqrt(x₀)))) + ...
#                                   sqrt(x₀))) / 1.031
# 18          9.286e-05  1.079e-02  y = (sqrt(tanh(x₀)) / (sqrt(x₀) + sqrt(sqrt(tanh(inv(x₀) - sqr...
#                                   t(x₀)))))) / sqrt(1.0647)
# 19          7.667e-05  1.916e-01  y = (sqrt(x₀) / (sqrt(tanh(sqrt(((inv(x₀) / x₀) / x₀) - x₀))) ...
#                                   + sqrt(x₀))) / 1.0647
# 20          7.645e-05  2.839e-03  y = (sqrt(tanh(tanh(x₀))) / (sqrt(sqrt(tanh(inv(x₀) - sqrt(sqr...
#                                   t(x₀))))) + sqrt(tanh(x₀)))) / 1.031
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.640e+04
# Head worker occupation: 3.9%
# Progress: 1301 / 5000 total iterations (26.020%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.155e+01  1.594e+01  y = -3.0149
# 2           1.382e-02  6.728e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.332e-04  9.369e-02  y = tanh(inv(1.1368 + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  2.254e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 14          1.259e-04  1.082e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * (x₀ * x₀))) + sqrt(1.1466)))
# 15          1.184e-04  6.214e-02  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ))))
# 16          1.036e-04  1.335e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(tanh(sqrt(tanh(inv(sqrt...
#                                   (x₀)) - x₀)))))
# 17          9.387e-05  9.829e-02  y = (sqrt(tanh(x₀)) / (sqrt(sqrt(tanh(inv(x₀) - sqrt(x₀)))) + ...
#                                   sqrt(x₀))) / 1.031
# 18          9.286e-05  1.079e-02  y = (sqrt(tanh(x₀)) / (sqrt(x₀) + sqrt(sqrt(tanh(inv(x₀) - sqr...
#                                   t(x₀)))))) / sqrt(1.0647)
# 19          7.667e-05  1.916e-01  y = (sqrt(x₀) / (sqrt(tanh(sqrt(((inv(x₀) / x₀) / x₀) - x₀))) ...
#                                   + sqrt(x₀))) / 1.0647
# 20          7.645e-05  2.839e-03  y = (sqrt(tanh(tanh(x₀))) / (sqrt(sqrt(tanh(inv(x₀) - sqrt(sqr...
#                                   t(x₀))))) + sqrt(tanh(x₀)))) / 1.031
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.780e+04
# Head worker occupation: 4.1%
# Progress: 1396 / 5000 total iterations (27.920%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.596e-02  1.594e+01  y = x₀
# 2           1.382e-02  1.202e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.332e-04  9.369e-02  y = tanh(inv(1.1368 + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  2.254e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 14          1.259e-04  1.082e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * (x₀ * x₀))) + sqrt(1.1466)))
# 15          1.184e-04  6.214e-02  y = tanh(inv(tanh(sqrt(inv(x₀ * x₀) - x₀)) + sqrt(inv(tanh(x₀)...
#                                   ))))
# 16          8.408e-05  3.419e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(tanh(tanh(sqrt(tanh(inv...
#                                   (x₀) - x₀))))))
# 18          7.638e-05  4.807e-02  y = (sqrt(x₀) / (sqrt(tanh(sqrt(inv(x₀) - x₀) / tanh(0.81511))...
#                                   ) + sqrt(x₀))) / 1.0647
# 19          7.476e-05  2.134e-02  y = (sqrt(x₀) / (sqrt(tanh(sqrt((inv(x₀) / x₀) - x₀))) + (sqrt...
#                                   (x₀) / 0.91154))) / 1.031
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.870e+04
# Head worker occupation: 4.1%
# Progress: 1485 / 5000 total iterations (29.700%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.596e-02  1.594e+01  y = x₀
# 2           1.382e-02  1.202e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.332e-04  9.369e-02  y = tanh(inv(1.1368 + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  2.254e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 14          1.259e-04  1.082e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * (x₀ * x₀))) + sqrt(1.1466)))
# 15          7.834e-05  4.748e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 18          7.638e-05  8.478e-03  y = (sqrt(x₀) / (sqrt(tanh(sqrt(inv(x₀) - x₀) / tanh(0.81511))...
#                                   ) + sqrt(x₀))) / 1.0647
# 19          7.476e-05  2.134e-02  y = (sqrt(x₀) / (sqrt(tanh(sqrt((inv(x₀) / x₀) - x₀))) + (sqrt...
#                                   (x₀) / 0.91154))) / 1.031
# 20          7.269e-05  2.810e-02  y = (sqrt(x₀) / (sqrt(tanh(sqrt(inv(x₀) - x₀) / tanh(sqrt(tanh...
#                                   (x₀))))) + sqrt(x₀))) / 1.0647
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.840e+04
# Head worker occupation: 4.0%
# Progress: 1563 / 5000 total iterations (31.260%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.596e-02  1.594e+01  y = x₀
# 2           1.382e-02  1.202e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.332e-04  9.369e-02  y = tanh(inv(1.1368 + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  2.254e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 14          1.259e-04  1.082e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * (x₀ * x₀))) + sqrt(1.1466)))
# 15          7.834e-05  4.748e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 18          7.638e-05  8.478e-03  y = (sqrt(x₀) / (sqrt(tanh(sqrt(inv(x₀) - x₀) / tanh(0.81511))...
#                                   ) + sqrt(x₀))) / 1.0647
# 19          7.197e-05  5.945e-02  y = (sqrt(x₀) / (sqrt(tanh(sqrt(inv(x₀ * x₀) - x₀) * 1.1714)) ...
#                                   + sqrt(x₀))) / 1.0647
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.730e+04
# Head worker occupation: 4.1%
# Progress: 1642 / 5000 total iterations (32.840%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.596e-02  1.594e+01  y = x₀
# 2           1.382e-02  1.202e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.332e-04  9.369e-02  y = tanh(inv(1.1368 + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  2.254e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 14          1.228e-04  3.623e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * (x₀ * x₀))) + sqrt(1.1561)))
# 15          7.834e-05  4.494e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 18          7.638e-05  8.478e-03  y = (sqrt(x₀) / (sqrt(tanh(sqrt(inv(x₀) - x₀) / tanh(0.81511))...
#                                   ) + sqrt(x₀))) / 1.0647
# 19          7.197e-05  5.945e-02  y = (sqrt(x₀) / (sqrt(tanh(sqrt(inv(x₀ * x₀) - x₀) * 1.1714)) ...
#                                   + sqrt(x₀))) / 1.0647
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.590e+04
# Head worker occupation: 4.2%
# Progress: 1727 / 5000 total iterations (34.540%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.596e-02  1.594e+01  y = x₀
# 2           1.382e-02  1.202e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.332e-04  9.369e-02  y = tanh(inv(1.1368 + sqrt(inv(x₀) - (x₀ * x₀))))
# 12          1.327e-04  3.799e-03  y = tanh(inv(sqrt(1.2992) + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  4.129e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 14          1.228e-04  3.623e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * (x₀ * x₀))) + sqrt(1.1561)))
# 15          7.834e-05  4.494e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 16          7.106e-05  9.753e-02  y = (-1.6463 * -0.50756) * inv(sqrt(inv(x₀)) + sqrt(sqrt(x₀ - ...
#                                   (x₀ * x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.580e+04
# Head worker occupation: 4.2%
# Progress: 1813 / 5000 total iterations (36.260%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.596e-02  1.594e+01  y = x₀
# 2           1.382e-02  1.202e+00  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.052e-03  1.899e+00  y = sqrt(x₀) / 1.77
# 5           8.765e-04  1.821e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) / 2.0551) - -0.057866
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.332e-04  9.369e-02  y = tanh(inv(1.1368 + sqrt(inv(x₀) - (x₀ * x₀))))
# 12          1.327e-04  3.799e-03  y = tanh(inv(sqrt(1.2992) + sqrt(inv(x₀) - (x₀ * x₀))))
# 13          1.273e-04  4.129e-02  y = tanh(inv(sqrt(sqrt(tanh(inv(x₀) - x₀))) + sqrt(inv(x₀))))
# 14          1.228e-04  3.623e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * (x₀ * x₀))) + sqrt(1.1561)))
# 15          7.834e-05  4.494e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 16          7.106e-05  9.753e-02  y = (-1.6463 * -0.50756) * inv(sqrt(inv(x₀)) + sqrt(sqrt(x₀ - ...
# ...
# 19          6.982e-05  7.556e-03  y = (-1.6463 * -0.50756) * inv(sqrt(inv(x₀)) + sqrt(sqrt((x₀ -...
#                                    (x₀ * x₀)) * sqrt(1.0644))))
# 20          6.734e-05  3.604e-02  y = tanh(inv(sqrt(sqrt(((inv(x₀) / x₀) - x₀) * 2.0525)) + sqrt...
#                                   (tanh(tanh(x₀)) / sqrt(x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.370e+04
# Head worker occupation: 3.8%
# Progress: 4474 / 5000 total iterations (89.480%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.411e-02  1.594e+01  y = 0.39939
# 2           1.382e-02  2.088e-02  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.051e-03  1.900e+00  y = sqrt(x₀) / 1.7738
# 5           8.765e-04  1.814e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) * 0.48655) + 0.057896
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.326e-04  9.586e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * x₀)) + 1.1414))
# 12          1.264e-04  4.817e-02  y = tanh(inv(sqrt(inv(x₀) - x₀) + sqrt(x₀)) / 1.2458)
# 13          1.140e-04  1.026e-01  y = tanh(inv(1.1812 * (sqrt(inv(x₀) - x₀) + sqrt(sqrt(x₀)))))
# 14          9.380e-05  1.955e-01  y = tanh(inv(1.1812 * ((sqrt(inv(x₀) - x₀) / 0.91481) + sqrt(x...
#                                   ₀))))
# 15          7.834e-05  1.800e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 16          7.042e-05  1.066e-01  y = (-0.50663 * -1.646) * inv(sqrt(inv(x₀)) + sqrt(sqrt(x₀ - (...
#                                   x₀ * x₀))))
# 18          7.035e-05  5.465e-04  y = (-1.6463 * -0.50756) * inv(sqrt(sqrt(x₀ - (x₀ * x₀)) / 0.9...
#                                   7157) + sqrt(inv(x₀)))
# 19          6.982e-05  7.556e-03  y = (-1.6463 * -0.50756) * inv(sqrt(inv(x₀)) + sqrt(sqrt((x₀ -...
#                                    (x₀ * x₀)) * sqrt(1.0644))))
# 20          6.734e-05  3.604e-02  y = tanh(inv(sqrt(sqrt(((inv(x₀) / x₀) - x₀) * 2.0525)) + sqrt...
#                                   (tanh(tanh(x₀)) / sqrt(x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.350e+04
# Head worker occupation: 3.8%
# Progress: 4571 / 5000 total iterations (91.420%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.411e-02  1.594e+01  y = 0.39939
# 2           1.382e-02  2.088e-02  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.051e-03  1.900e+00  y = sqrt(x₀) / 1.7738
# 5           8.765e-04  1.814e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) * 0.48655) + 0.057896
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.326e-04  9.586e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * x₀)) + 1.1414))
# 12          1.264e-04  4.817e-02  y = tanh(inv(sqrt(inv(x₀) - x₀) + sqrt(x₀)) / 1.2458)
# 13          1.140e-04  1.026e-01  y = tanh(inv(1.1812 * (sqrt(inv(x₀) - x₀) + sqrt(sqrt(x₀)))))
# 14          9.380e-05  1.955e-01  y = tanh(inv(1.1812 * ((sqrt(inv(x₀) - x₀) / 0.91481) + sqrt(x...
#                                   ₀))))
# 15          7.834e-05  1.800e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 16          7.042e-05  1.066e-01  y = (-0.50663 * -1.646) * inv(sqrt(inv(x₀)) + sqrt(sqrt(x₀ - (...
#                                   x₀ * x₀))))
# 18          7.035e-05  5.465e-04  y = (-1.6463 * -0.50756) * inv(sqrt(sqrt(x₀ - (x₀ * x₀)) / 0.9...
#                                   7157) + sqrt(inv(x₀)))
# 19          6.982e-05  7.556e-03  y = (-1.6463 * -0.50756) * inv(sqrt(inv(x₀)) + sqrt(sqrt((x₀ -...
#                                    (x₀ * x₀)) * sqrt(1.0644))))
# 20          6.734e-05  3.604e-02  y = tanh(inv(sqrt(sqrt(((inv(x₀) / x₀) - x₀) * 2.0525)) + sqrt...
#                                   (tanh(tanh(x₀)) / sqrt(x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.380e+04
# Head worker occupation: 3.8%
# Progress: 4676 / 5000 total iterations (93.520%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.411e-02  1.594e+01  y = 0.39939
# 2           1.382e-02  2.088e-02  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.051e-03  1.900e+00  y = sqrt(x₀) / 1.7738
# 5           8.765e-04  1.814e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) * 0.48655) + 0.057896
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.326e-04  9.586e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * x₀)) + 1.1414))
# 12          1.264e-04  4.817e-02  y = tanh(inv(sqrt(inv(x₀) - x₀) + sqrt(x₀)) / 1.2458)
# 13          1.140e-04  1.026e-01  y = tanh(inv(1.1812 * (sqrt(inv(x₀) - x₀) + sqrt(sqrt(x₀)))))
# 14          9.380e-05  1.955e-01  y = tanh(inv(1.1812 * ((sqrt(inv(x₀) - x₀) / 0.91481) + sqrt(x...
#                                   ₀))))
# 15          7.834e-05  1.800e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 16          7.042e-05  1.066e-01  y = (-0.50663 * -1.646) * inv(sqrt(inv(x₀)) + sqrt(sqrt(x₀ - (...
#                                   x₀ * x₀))))
# 18          7.035e-05  5.465e-04  y = (-1.6463 * -0.50756) * inv(sqrt(sqrt(x₀ - (x₀ * x₀)) / 0.9...
#                                   7157) + sqrt(inv(x₀)))
# 19          6.982e-05  7.556e-03  y = (-1.6463 * -0.50756) * inv(sqrt(inv(x₀)) + sqrt(sqrt((x₀ -...
#                                    (x₀ * x₀)) * sqrt(1.0644))))
# 20          6.734e-05  3.604e-02  y = tanh(inv(sqrt(sqrt(((inv(x₀) / x₀) - x₀) * 2.0525)) + sqrt...
#                                   (tanh(tanh(x₀)) / sqrt(x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.490e+04
# Head worker occupation: 3.8%
# Progress: 4785 / 5000 total iterations (95.700%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.411e-02  1.594e+01  y = 0.39939
# 2           1.382e-02  2.088e-02  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.051e-03  1.900e+00  y = sqrt(x₀) / 1.7738
# 5           8.765e-04  1.814e-01  y = tanh(sqrt(x₀) / 1.6408)
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) * 0.48655) + 0.057896
# 9           1.606e-04  4.803e-01  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.326e-04  9.586e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * x₀)) + 1.1414))
# 12          1.264e-04  4.817e-02  y = tanh(inv(sqrt(inv(x₀) - x₀) + sqrt(x₀)) / 1.2458)
# 13          1.140e-04  1.026e-01  y = tanh(inv(1.1812 * (sqrt(inv(x₀) - x₀) + sqrt(sqrt(x₀)))))
# 14          9.380e-05  1.955e-01  y = tanh(inv(1.1812 * ((sqrt(inv(x₀) - x₀) / 0.91481) + sqrt(x...
#                                   ₀))))
# 15          7.834e-05  1.800e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 16          7.042e-05  1.066e-01  y = (-0.50663 * -1.646) * inv(sqrt(inv(x₀)) + sqrt(sqrt(x₀ - (...
#                                   x₀ * x₀))))
# 18          7.035e-05  5.465e-04  y = (-1.6463 * -0.50756) * inv(sqrt(sqrt(x₀ - (x₀ * x₀)) / 0.9...
#                                   7157) + sqrt(inv(x₀)))
# 19          6.982e-05  7.556e-03  y = (-1.6463 * -0.50756) * inv(sqrt(inv(x₀)) + sqrt(sqrt((x₀ -...
#                                    (x₀ * x₀)) * sqrt(1.0644))))
# 20          6.734e-05  3.604e-02  y = tanh(inv(sqrt(sqrt(((inv(x₀) / x₀) - x₀) * 2.0525)) + sqrt...
#                                   (tanh(tanh(x₀)) / sqrt(x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.620e+04
# Head worker occupation: 3.9%
# Progress: 4891 / 5000 total iterations (97.820%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.411e-02  1.594e+01  y = 0.39939
# 2           1.382e-02  2.088e-02  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.051e-03  1.900e+00  y = sqrt(x₀) / 1.7738
# 5           8.765e-04  1.814e-01  y = tanh(sqrt(x₀ / 2.6922))
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) * 0.48655) + 0.057896
# 8           6.144e-04  4.973e-02  y = inv(log(inv(x₀)) + 1.6698) - 0.031691
# 9           1.606e-04  1.342e+00  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.326e-04  9.586e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * x₀)) + 1.1414))
# 12          1.264e-04  4.817e-02  y = tanh(inv(sqrt(inv(x₀) - x₀) + sqrt(x₀)) / 1.2458)
# 13          1.140e-04  1.026e-01  y = tanh(inv(1.1812 * (sqrt(inv(x₀) - x₀) + sqrt(sqrt(x₀)))))
# 14          9.380e-05  1.955e-01  y = tanh(inv(1.1812 * ((sqrt(inv(x₀) - x₀) / 0.91481) + sqrt(x...
#                                   ₀))))
# 15          7.834e-05  1.800e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 16          7.042e-05  1.066e-01  y = (-0.50663 * -1.646) * inv(sqrt(inv(x₀)) + sqrt(sqrt(x₀ - (...
#                                   x₀ * x₀))))
# 18          7.035e-05  5.465e-04  y = (-1.6463 * -0.50756) * inv(sqrt(sqrt(x₀ - (x₀ * x₀)) / 0.9...
#                                   7157) + sqrt(inv(x₀)))
# 19          6.982e-05  7.556e-03  y = (-1.6463 * -0.50756) * inv(sqrt(inv(x₀)) + sqrt(sqrt((x₀ -...
#                                    (x₀ * x₀)) * sqrt(1.0644))))
# 20          6.734e-05  3.604e-02  y = tanh(inv(sqrt(sqrt(((inv(x₀) / x₀) - x₀) * 2.0525)) + sqrt...
#                                   (tanh(tanh(x₀)) / sqrt(x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.570e+04
# Head worker occupation: 3.9%
# Progress: 4993 / 5000 total iterations (99.860%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.411e-02  1.594e+01  y = 0.39939
# 2           1.382e-02  2.088e-02  y = tanh(0.40278)
# 3           7.027e-03  6.766e-01  y = tanh(tanh(x₀))
# 4           1.051e-03  1.900e+00  y = sqrt(x₀) / 1.7738
# 5           8.765e-04  1.814e-01  y = tanh(sqrt(x₀ / 2.6922))
# 6           6.787e-04  2.557e-01  y = (sqrt(x₀) * 0.48655) + 0.057896
# 8           6.144e-04  4.973e-02  y = inv(log(inv(x₀)) + 1.6698) - 0.031691
# 9           1.606e-04  1.342e+00  y = tanh(inv(sqrt(inv(x₀) - x₀) + 1.2276))
# 11          1.326e-04  9.586e-02  y = tanh(inv(sqrt(inv(x₀) - (x₀ * x₀)) + 1.1414))
# 12          1.264e-04  4.817e-02  y = tanh(inv(sqrt(inv(x₀) - x₀) + sqrt(x₀)) / 1.2458)
# 13          1.140e-04  1.026e-01  y = tanh(inv(1.1812 * (sqrt(inv(x₀) - x₀) + sqrt(sqrt(x₀)))))
# 14          9.380e-05  1.955e-01  y = tanh(inv(1.1812 * ((sqrt(inv(x₀) - x₀) / 0.91481) + sqrt(x...
#                                   ₀))))
# 15          7.834e-05  1.800e-01  y = 0.87608 * inv(sqrt(inv(x₀)) + sqrt(sqrt(sqrt(x₀) - (x₀ * x...
#                                   ₀))))
# 16          7.042e-05  1.066e-01  y = (-0.50663 * -1.646) * inv(sqrt(inv(x₀)) + sqrt(sqrt(x₀ - (...
#                                   x₀ * x₀))))
# 18          7.035e-05  5.465e-04  y = (-1.6463 * -0.50756) * inv(sqrt(sqrt(x₀ - (x₀ * x₀)) / 0.9...
#                                   7157) + sqrt(inv(x₀)))
# 19          6.982e-05  7.556e-03  y = (-1.6463 * -0.50756) * inv(sqrt(inv(x₀)) + sqrt(sqrt((x₀ -...
#                                    (x₀ * x₀)) * sqrt(1.0644))))
# 20          6.734e-05  3.604e-02  y = tanh(inv(sqrt(sqrt(((inv(x₀) / x₀) - x₀) * 2.0525)) + sqrt...
#                                   (tanh(tanh(x₀)) / sqrt(x₀))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          0.3993924
# 	1         0.020882                                    tanh(0.4027758)
# 	2         0.676616                                     tanh(tanh(x0))
# 	3         1.900120                               sqrt(x0) / 1.7738394
# 	4         0.181429                          tanh(sqrt(x0 / 2.692194))
# 	5         0.255745                   (sqrt(x0) * 0.486554) + 0.057896
# 	6         0.049729        inv(log(inv(x0)) + 1.6697814) - 0.031690534
# 	7         1.341560          tanh(inv(sqrt(inv(x0) - x0) + 1.2276471))
# 	8         0.095860   tanh(inv(sqrt(inv(x0) - (x0 * x0)) + 1.1414489))
# 	9         0.048174  tanh(inv(sqrt(inv(x0) - x0) + sqrt(x0)) / 1.24...
# 	10        0.102630  tanh(inv(1.1812416 * (sqrt(inv(x0) - x0) + sqr...
# 	11  >>>>  0.195498  tanh(inv(1.1812416 * ((sqrt(inv(x0) - x0) / 0....
# 	12        0.180021  0.87608135 * inv(sqrt(inv(x0)) + sqrt(sqrt(sqr...
# 	13        0.106594  (-0.5066333 * -1.6460458) * inv(sqrt(inv(x0)) ...
# 	14        0.000547  (-1.6463317 * -0.50755954) * inv(sqrt(sqrt(x0 ...
# 	15        0.007556  (-1.6463317 * -0.50755954) * inv(sqrt(inv(x0))...
# 	16        0.036045  tanh(inv(sqrt(sqrt(((inv(x0) / x0) - x0) * 2.0...
#
# 	        loss  complexity
# 	0   0.014115           1
# 	1   0.013823           2
# 	2   0.007027           3
# 	3   0.001051           4
# 	4   0.000876           5
# 	5   0.000679           6
# 	6   0.000614           8
# 	7   0.000161           9
# 	8   0.000133          11
# 	9   0.000126          12
# 	10  0.000114          13
# 	11  0.000094          14
# 	12  0.000078          15
# 	13  0.000070          16
# 	14  0.000070          18
# 	15  0.000070          19
# 	16  0.000067          20
# ]

# %%
pysr_model_padded = PySRRegressor(
    binary_operators=["+", "-", "*", "/"],
    unary_operators=["exp", "log", "tanh", "sqrt", "inv(x) = 1/x"],
    extra_sympy_mappings={"inv": lambda x: 1/x},
    niterations=100,  # Adjust depending on the complexity of your function
    populations=50,   # More populations to better explore the equation space
    progress=True,     # Display progress bar
    random_state = False,
)

x = df.right_borders.values
y = np.cumsum(df.probs).values
x_padded = np.concatenate((np.linspace(-1,0,1000), x, np.linspace(1,2,1000)))[:,None]
y_padded = np.concatenate((np.zeros_like(np.linspace(1,2,1000)), y, np.ones_like(np.linspace(1,2,1000))))


pysr_model_padded.fit(x_padded, y_padded)
# Out:
# [ Info: Started!
# Expressions evaluated per second: 9.670e+03
# Head worker occupation: 6.8%
# Progress: 22 / 5000 total iterations (0.440%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           4.420e-02  7.710e-02  y = tanh(tanh(x₀))
# 4           3.430e-02  2.535e-01  y = tanh(x₀ / 1.3304)
# 5           1.582e-02  7.740e-01  y = exp(x₀ - inv(0.64828))
# 7           1.259e-02  1.142e-01  y = tanh(exp(x₀ + inv(tanh(-0.94973))))
# 10          1.216e-02  1.145e-02  y = ((x₀ - (tanh(-0.94783) - x₀)) + x₀) * 0.17666
# 11          1.184e-02  2.742e-02  y = tanh((x₀ - -0.17374) * tanh((x₀ * 0.37229) - -0.34795))
# 12          1.019e-02  1.499e-01  y = tanh(exp(inv(tanh(-0.73113 - (x₀ * tanh(x₀)))) + x₀))
# 13          6.350e-03  4.727e-01  y = tanh(exp(inv(tanh(inv(inv(-0.59031)) - (x₀ * 0.54426))) + ...
#                                   x₀))
# 16          6.318e-03  1.698e-03  y = tanh(exp(inv(tanh(inv(inv(-0.59031)) - (tanh(tanh(sqrt(0.5...
#                                   4426))) * x₀))) + x₀))
# 19          6.015e-03  1.637e-02  y = tanh(exp(inv(inv(inv(-0.59031)) - ((tanh(0.2454) * (x₀ + -...
#                                   0.00012119)) - 0.12301)) + x₀) * 1.2765)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.620e+04
# Head worker occupation: 5.0%
# Progress: 105 / 5000 total iterations (2.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.702e-03  7.344e-01  y = 0.45426 * (x₀ + 0.45426)
# 7           8.801e-03  4.877e-02  y = tanh((exp(x₀) + x₀) * 0.20275)
# 9           6.906e-03  1.212e-01  y = tanh((exp(x₀ + x₀) + x₀) * 0.10657)
# 10          6.006e-03  1.397e-01  y = tanh((exp(x₀) + exp(x₀ + x₀)) * 0.082971)
# 12          5.965e-03  3.380e-03  y = tanh(((exp(x₀ + x₀) + exp(x₀)) + x₀) * 0.082971)
# 13          5.614e-03  6.066e-02  y = tanh(0.082971 * (((exp(x₀ + x₀) + x₀) + 0.74011) + x₀))
# 14          5.448e-03  3.007e-02  y = tanh(((exp(x₀ + (x₀ * x₀)) + x₀) + exp(x₀)) * 0.082971)
# 16          5.246e-03  1.885e-02  y = tanh(((inv(1.184) + x₀) + (exp(x₀ + (x₀ - 1.1267)) * x₀)) ...
#                                   * 0.20408)
# 17          5.181e-03  1.246e-02  y = tanh(0.082971 * ((((exp((x₀ * x₀) + x₀) + x₀) + 0.74011) +...
#                                    x₀) + x₀))
# 18          4.663e-03  1.054e-01  y = tanh(exp((tanh(tanh(((inv(-0.97053) + x₀) / 0.19649) / 0.1...
#                                   9649)) - (-0.11965 + 0.817)) + x₀))
# 19          2.596e-03  5.858e-01  y = tanh(exp((tanh(0.39137 / ((-0.88738 + x₀) - 0.11335)) - ((...
#                                   0.26286 - tanh(x₀)) + 0.93438)) + x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.770e+04
# Head worker occupation: 4.5%
# Progress: 174 / 5000 total iterations (3.480%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.521e-03  7.534e-01  y = 0.44998 * (0.44998 + x₀)
# 6           9.388e-03  1.404e-02  y = 0.44998 * (tanh(0.44998) + x₀)
# 7           8.801e-03  6.460e-02  y = tanh((exp(x₀) + x₀) * 0.20275)
# 8           6.376e-03  3.223e-01  y = tanh((exp(x₀) - tanh(0.6891)) / 2.5846)
# 9           6.049e-03  5.262e-02  y = tanh(exp(x₀ - sqrt(exp(1.2745 - x₀))))
# 10          6.006e-03  7.214e-03  y = tanh((exp(x₀) + exp(x₀ + x₀)) * 0.082971)
# 12          5.965e-03  3.380e-03  y = tanh(((exp(x₀ + x₀) + exp(x₀)) + x₀) * 0.082971)
# 13          5.465e-03  8.755e-02  y = tanh(0.082971 * (((x₀ + exp(x₀ + x₀)) + 0.86677) + x₀))
# 14          5.367e-03  1.819e-02  y = tanh(exp((tanh(tanh((x₀ + inv(-0.97053)) / 0.19649)) - 0.8...
#                                   17) + x₀))
# 15          5.340e-03  5.068e-03  y = tanh(0.083234 * (((tanh(x₀) + exp(x₀ + x₀)) + x₀) + exp(-0...
#                                   .057578)))
# 16          4.964e-03  7.297e-02  y = tanh(((exp(x₀ + ((x₀ * x₀) * x₀)) + x₀) + exp(x₀)) * 0.082...
#                                   971)
# 17          4.687e-03  5.748e-02  y = tanh(exp((tanh(((inv(-0.97053) + x₀) / 0.19649) / 0.19649)...
#                                    - (-0.39537 + 0.817)) + x₀))
# 18          4.663e-03  4.998e-03  y = tanh(exp((tanh(tanh(((inv(-0.97053) + x₀) / 0.19649) / 0.1...
#                                   9649)) - (-0.11965 + 0.817)) + x₀))
# 19          2.596e-03  5.858e-01  y = tanh(exp((tanh(0.39137 / ((-0.88738 + x₀) - 0.11335)) - ((...
#                                   0.26286 - tanh(x₀)) + 0.93438)) + x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.840e+04
# Head worker occupation: 5.2%
# Progress: 244 / 5000 total iterations (4.880%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.449e-03  7.610e-01  y = 0.44559 * (0.44998 + x₀)
# 6           9.388e-03  6.444e-03  y = 0.44998 * (tanh(0.44998) + x₀)
# 7           8.801e-03  6.460e-02  y = tanh((exp(x₀) + x₀) * 0.20275)
# 8           6.376e-03  3.223e-01  y = tanh((exp(x₀) - tanh(0.6891)) / 2.5846)
# 9           6.049e-03  5.262e-02  y = tanh(exp(x₀ - sqrt(exp(1.2745 - x₀))))
# 10          6.006e-03  7.214e-03  y = tanh((exp(x₀) + exp(x₀ + x₀)) * 0.082971)
# 11          5.814e-03  3.246e-02  y = tanh((tanh(exp(x₀)) + (exp(x₀) * x₀)) * 0.22636)
# 13          5.445e-03  3.280e-02  y = tanh((exp(x₀ + x₀) + ((x₀ + x₀) + 0.94128)) * 0.082971)
# 14          5.341e-03  1.930e-02  y = tanh((exp(x₀ + x₀) + ((x₀ + tanh(x₀)) + 0.94128)) * 0.0829...
#                                   71)
# 15          3.770e-03  3.484e-01  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(x₀ + inv(-0.99786))) - ...
#                                   tanh(1.3577))))
# 18          2.979e-03  7.850e-02  y = tanh(exp((tanh(0.39137 / ((-0.88738 + x₀) - 0.11335)) - ((...
#                                   0.26286 - x₀) + 0.93438)) + x₀))
# 19          2.596e-03  1.375e-01  y = tanh(exp((tanh(0.39137 / ((-0.88738 + x₀) - 0.11335)) - ((...
#                                   0.26286 - tanh(x₀)) + 0.93438)) + x₀))
# 20          2.297e-03  1.225e-01  y = tanh(exp((tanh(0.39137 / (tanh(-0.88738 + x₀) - 0.11335)) ...
#                                   - ((0.26286 - tanh(x₀)) + 0.93438)) + x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.970e+04
# Head worker occupation: 6.0%
# Progress: 310 / 5000 total iterations (6.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.449e-03  7.610e-01  y = 0.44559 * (0.44998 + x₀)
# 6           7.821e-03  1.890e-01  y = tanh(exp(exp(x₀)) * 0.056905)
# 7           6.372e-03  2.049e-01  y = tanh((0.38326 * exp(x₀)) - 0.2264)
# 8           5.990e-03  6.186e-02  y = tanh((exp(exp(x₀)) + x₀) * 0.059402)
# 9           5.990e-03  5.102e-05  y = tanh((exp(exp(x₀)) + x₀) * tanh(0.059353))
# 10          5.547e-03  7.684e-02  y = tanh((exp(exp(x₀)) + (x₀ + x₀)) * 0.054753)
# 11          5.273e-03  5.069e-02  y = tanh((exp(exp(x₀)) + tanh(x₀ + x₀)) * 0.056905)
# 12          4.010e-03  2.737e-01  y = tanh((tanh(x₀ / exp(-2.2003)) + exp(exp(x₀))) * 0.056905)
# 13          4.009e-03  2.414e-04  y = tanh((tanh(x₀ / tanh(exp(-2.2003))) + exp(exp(x₀))) * 0.05...
#                                   6905)
# 14          3.809e-03  5.119e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(x₀ + -0.99786)) - tanh(...
#                                   1.3577))))
# 15          3.465e-03  9.480e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(tanh(x₀ + -0.99786))) -...
#                                    tanh(1.3577))))
# 17          2.617e-03  1.404e-01  y = tanh(exp((x₀ * 1.6194) + (tanh(inv((x₀ * x₀) + inv(-0.9978...
#                                   6))) - tanh(1.3577))))
# 19          2.445e-03  3.395e-02  y = tanh(exp((tanh(0.39137 / ((-0.88738 + x₀) - 0.11335)) - ((...
#                                   0.26286 - x₀) + inv(0.93438))) + x₀))
# 20          2.297e-03  6.256e-02  y = tanh(exp((tanh(0.39137 / (tanh(-0.88738 + x₀) - 0.11335)) ...
#                                   - ((0.26286 - tanh(x₀)) + 0.93438)) + x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.940e+04
# Head worker occupation: 6.1%
# Progress: 363 / 5000 total iterations (7.260%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.449e-03  7.610e-01  y = 0.44559 * (0.44998 + x₀)
# 6           7.000e-03  3.000e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           6.372e-03  9.394e-02  y = tanh((0.38326 * exp(x₀)) - 0.2264)
# 8           5.990e-03  6.191e-02  y = tanh((x₀ + exp(exp(x₀))) * 0.059287)
# 9           5.950e-03  6.615e-03  y = tanh(0.059402 * (tanh(x₀) + exp(exp(x₀))))
# 10          5.547e-03  7.022e-02  y = tanh((exp(exp(x₀)) + (x₀ + x₀)) * 0.054753)
# 11          3.975e-03  3.332e-01  y = tanh((tanh(x₀ / 0.039461) + exp(exp(x₀))) * 0.056905)
# 14          3.809e-03  1.422e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(x₀ + -0.99786)) - tanh(...
#                                   1.3577))))
# 15          3.465e-03  9.480e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(tanh(x₀ + -0.99786))) -...
#                                    tanh(1.3577))))
# 16          3.424e-03  1.170e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(tanh(x₀ + inv(-0.99786)...
#                                   ))) - tanh(1.3577))))
# 17          2.617e-03  2.690e-01  y = tanh(exp((x₀ * 1.6194) + (tanh(inv((x₀ * x₀) + inv(-0.9978...
#                                   6))) - tanh(1.3577))))
# 19          2.445e-03  3.395e-02  y = tanh(exp((tanh(0.39137 / ((-0.88738 + x₀) - 0.11335)) - ((...
#                                   0.26286 - x₀) + inv(0.93438))) + x₀))
# 20          2.297e-03  6.256e-02  y = tanh(exp((tanh(0.39137 / (tanh(-0.88738 + x₀) - 0.11335)) ...
#                                   - ((0.26286 - tanh(x₀)) + 0.93438)) + x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.730e+04
# Head worker occupation: 6.4%
# Progress: 417 / 5000 total iterations (8.340%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.424e-03  7.636e-01  y = 0.44559 * (0.44559 + x₀)
# 6           7.000e-03  2.973e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           6.372e-03  9.394e-02  y = tanh((0.38326 * exp(x₀)) - 0.2264)
# 8           5.990e-03  6.191e-02  y = tanh((x₀ + exp(exp(x₀))) * 0.059287)
# 9           5.950e-03  6.615e-03  y = tanh(0.059402 * (tanh(x₀) + exp(exp(x₀))))
# 10          5.547e-03  7.022e-02  y = tanh((exp(exp(x₀)) + (x₀ + x₀)) * 0.054753)
# 11          3.975e-03  3.332e-01  y = tanh((tanh(x₀ / 0.039461) + exp(exp(x₀))) * 0.056905)
# 13          3.972e-03  3.976e-04  y = tanh((tanh((x₀ / 0.039461) - x₀) + exp(exp(x₀))) * 0.05690...
#                                   5)
# 14          3.809e-03  4.187e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(x₀ + -0.99786)) - tanh(...
#                                   1.3577))))
# 15          3.465e-03  9.480e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(tanh(x₀ + -0.99786))) -...
#                                    tanh(1.3577))))
# 16          2.620e-03  2.793e-01  y = tanh(exp((x₀ * 1.6194) + (tanh(inv((x₀ * x₀) + -0.99786)) ...
#                                   - tanh(1.3577))))
# 17          2.617e-03  1.451e-03  y = tanh(exp((x₀ * 1.6194) + (tanh(inv((x₀ * x₀) + inv(-0.9978...
#                                   6))) - tanh(1.3577))))
# 18          2.549e-03  2.614e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv((x₀ * x₀) + inv(-0.9978...
#                                   6))) - sqrt(tanh(1.3577)))))
# 19          2.445e-03  4.176e-02  y = tanh(exp((tanh(0.39137 / ((-0.88738 + x₀) - 0.11335)) - ((...
#                                   0.26286 - x₀) + inv(0.93438))) + x₀))
# 20          2.162e-03  1.228e-01  y = tanh(exp(((x₀ * (1.6194 - x₀)) + (x₀ * 0.72791)) + (tanh(i...
#                                   nv(-0.99786 + x₀)) - tanh(1.3577))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.660e+04
# Head worker occupation: 6.1%
# Progress: 479 / 5000 total iterations (9.580%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.424e-03  7.636e-01  y = 0.44559 * (0.44559 + x₀)
# 6           7.000e-03  2.973e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           6.372e-03  9.394e-02  y = tanh((0.38326 * exp(x₀)) - 0.2264)
# 8           5.990e-03  6.191e-02  y = tanh((x₀ + exp(exp(x₀))) * 0.059287)
# 9           5.950e-03  6.615e-03  y = tanh(0.059402 * (tanh(x₀) + exp(exp(x₀))))
# 10          5.547e-03  7.022e-02  y = tanh((exp(exp(x₀)) + (x₀ + x₀)) * 0.054753)
# 11          3.975e-03  3.332e-01  y = tanh((tanh(x₀ / 0.039461) + exp(exp(x₀))) * 0.056905)
# 13          3.959e-03  1.997e-03  y = tanh((exp(exp(x₀)) + (tanh(x₀ / 0.050677) - 0.039461)) * 0...
#                                   .056905)
# 14          3.809e-03  3.867e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(x₀ + -0.99786)) - tanh(...
#                                   1.3577))))
# 15          3.465e-03  9.480e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(tanh(x₀ + -0.99786))) -...
#                                    tanh(1.3577))))
# 16          2.509e-03  3.228e-01  y = tanh(exp((x₀ * 1.6194) + (tanh(inv((x₀ * x₀) + -0.99786)) ...
#                                   - tanh(1.5231))))
# 19          2.327e-03  2.505e-02  y = tanh(exp((tanh(inv(-0.99786 + (x₀ * x₀))) - tanh(1.6194)) ...
#                                   + (tanh(x₀ * 0.72791) + x₀)))
# 20          2.162e-03  7.348e-02  y = tanh(exp(((x₀ * (1.6194 - x₀)) + (x₀ * 0.72791)) + (tanh(i...
#                                   nv(-0.99786 + x₀)) - tanh(1.3577))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.600e+04
# Head worker occupation: 5.8%
# Progress: 535 / 5000 total iterations (10.700%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.424e-03  7.636e-01  y = 0.44559 * (0.44559 + x₀)
# 6           7.000e-03  2.973e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 10          5.532e-03  2.376e-02  y = tanh(((exp(exp(x₀)) + x₀) + x₀) * 0.055617)
# 11          3.958e-03  3.346e-01  y = tanh((exp(exp(x₀)) + tanh(x₀ / 0.050677)) * 0.056905)
# 14          3.809e-03  1.282e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(x₀ + -0.99786)) - tanh(...
#                                   1.3577))))
# 15          3.465e-03  9.480e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(tanh(x₀ + -0.99786))) -...
#                                    tanh(1.3577))))
# 16          2.509e-03  3.228e-01  y = tanh(exp((x₀ * 1.6194) + (tanh(inv((x₀ * x₀) + -0.99786)) ...
#                                   - tanh(1.5231))))
# 19          2.327e-03  2.505e-02  y = tanh(exp((tanh(inv(-0.99786 + (x₀ * x₀))) - tanh(1.6194)) ...
#                                   + (tanh(x₀ * 0.72791) + x₀)))
# 20          2.162e-03  7.348e-02  y = tanh(exp(((x₀ * (1.6194 - x₀)) + (x₀ * 0.72791)) + (tanh(i...
#                                   nv(-0.99786 + x₀)) - tanh(1.3577))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.540e+04
# Head worker occupation: 5.8%
# Progress: 588 / 5000 total iterations (11.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.424e-03  7.636e-01  y = 0.44559 * (0.44559 + x₀)
# 6           7.000e-03  2.973e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 10          5.532e-03  2.376e-02  y = tanh(((exp(exp(x₀)) + x₀) + x₀) * 0.055617)
# 11          3.958e-03  3.346e-01  y = tanh((exp(exp(x₀)) + tanh(x₀ / 0.050677)) * 0.056905)
# 14          3.671e-03  2.515e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(tanh(inv(x₀ + -0.99786))) -...
#                                    1.087)))
# 15          3.465e-03  5.782e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(tanh(x₀ + -0.99786))) -...
#                                    tanh(1.3577))))
# 16          2.509e-03  3.228e-01  y = tanh(exp((x₀ * 1.6194) + (tanh(inv((x₀ * x₀) + -0.99786)) ...
#                                   - tanh(1.5231))))
# 19          2.327e-03  2.505e-02  y = tanh(exp((tanh(inv(-0.99786 + (x₀ * x₀))) - tanh(1.6194)) ...
#                                   + (tanh(x₀ * 0.72791) + x₀)))
# 20          2.162e-03  7.348e-02  y = tanh(exp(((x₀ * (1.6194 - x₀)) + (x₀ * 0.72791)) + (tanh(i...
#                                   nv(-0.99786 + x₀)) - tanh(1.3577))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.560e+04
# Head worker occupation: 5.5%
# Progress: 647 / 5000 total iterations (12.940%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.398e-03  7.663e-01  y = 0.44559 * (0.4378 + x₀)
# 6           7.000e-03  2.946e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 10          5.532e-03  2.376e-02  y = tanh(((exp(exp(x₀)) + x₀) + x₀) * 0.055617)
# 11          3.958e-03  3.346e-01  y = tanh((exp(exp(x₀)) + tanh(x₀ / 0.050677)) * 0.056905)
# 14          3.671e-03  2.515e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(tanh(inv(x₀ + -0.99786))) -...
#                                    1.087)))
# 15          3.465e-03  5.782e-02  y = tanh(exp((x₀ * 1.6194) + (tanh(inv(tanh(x₀ + -0.99786))) -...
#                                    tanh(1.3577))))
# 16          2.509e-03  3.228e-01  y = tanh(exp((x₀ * 1.6194) + (tanh(inv((x₀ * x₀) + -0.99786)) ...
#                                   - tanh(1.5231))))
# 17          2.494e-03  5.901e-03  y = tanh(exp((tanh(inv(tanh(-0.99786 + x₀))) - tanh(1.6194)) +...
#                                    (tanh(x₀) + tanh(x₀))))
# 18          1.846e-03  3.010e-01  y = tanh(exp((tanh(tanh(inv(x₀ + -0.99786))) - sqrt(1.4959)) +...
#                                    (1.4959 * tanh(x₀ + x₀))))
# 20          1.370e-03  1.491e-01  y = tanh(exp((tanh((inv(-0.99786 + x₀) + x₀) - tanh(x₀ * -1.33...
#                                   55)) - inv(exp(x₀))) + x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.580e+04
# Head worker occupation: 5.4%
# Progress: 713 / 5000 total iterations (14.260%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 10          5.532e-03  2.376e-02  y = tanh(((exp(exp(x₀)) + x₀) + x₀) * 0.055617)
# 11          3.958e-03  3.346e-01  y = tanh((exp(exp(x₀)) + tanh(x₀ / 0.050677)) * 0.056905)
# 12          3.954e-03  1.130e-03  y = tanh((exp(exp(x₀)) + tanh(inv(0.056905) * x₀)) * 0.056905)
# 13          3.163e-03  2.231e-01  y = tanh(exp((tanh(inv(-0.99786 + x₀)) - inv(exp(x₀))) + x₀))
# 15          1.969e-03  2.370e-01  y = tanh(exp((tanh(inv(-0.99786 + (x₀ * x₀))) - inv(exp(x₀))) ...
#                                   + x₀))
# 17          1.411e-03  1.668e-01  y = tanh(exp((tanh(inv(-0.99786 + x₀) + (x₀ + x₀)) - inv(exp(x...
#                                   ₀))) + x₀))
# 20          1.370e-03  9.733e-03  y = tanh(exp((tanh((inv(-0.99786 + x₀) + x₀) - tanh(x₀ * -1.33...
#                                   55)) - inv(exp(x₀))) + x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.570e+04
# Head worker occupation: 5.4%
# Progress: 765 / 5000 total iterations (15.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 10          5.532e-03  2.376e-02  y = tanh(((exp(exp(x₀)) + x₀) + x₀) * 0.055617)
# 11          3.958e-03  3.346e-01  y = tanh((exp(exp(x₀)) + tanh(x₀ / 0.050677)) * 0.056905)
# 12          3.954e-03  1.130e-03  y = tanh((exp(exp(x₀)) + tanh(inv(0.056905) * x₀)) * 0.056905)
# 13          3.163e-03  2.231e-01  y = tanh(exp((tanh(inv(-0.99786 + x₀)) - inv(exp(x₀))) + x₀))
# 14          3.152e-03  3.571e-03  y = tanh(exp((tanh(inv(inv(-0.99786) + x₀)) - inv(exp(x₀))) + ...
#                                   x₀))
# 15          1.969e-03  4.705e-01  y = tanh(exp((tanh(inv(-0.99786 + (x₀ * x₀))) - inv(exp(x₀))) ...
#                                   + x₀))
# 16          1.914e-03  2.856e-02  y = tanh(exp(x₀ + (tanh(inv(-0.99786 + x₀) / exp(x₀)) - inv(ex...
#                                   p(x₀)))))
# 17          1.411e-03  3.051e-01  y = tanh(exp((tanh(inv(-0.99786 + x₀) + (x₀ + x₀)) - inv(exp(x...
#                                   ₀))) + x₀))
# 19          5.260e-04  4.932e-01  y = tanh(exp((x₀ + (tanh(inv(x₀ + -0.99786)) - inv(exp(x₀ * ex...
#                                   p(2.5778))))) - sqrt(0.16015)))
# 20          3.991e-04  2.762e-01  y = tanh(exp((x₀ + (tanh(inv(tanh(x₀ + -0.99786))) - inv(exp(e...
#                                   xp(2.5778) * x₀)))) - sqrt(0.16015)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.680e+04
# Head worker occupation: 5.4%
# Progress: 830 / 5000 total iterations (16.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           4.774e-02  7.971e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 9           5.938e-03  1.792e-04  y = tanh(exp(x₀ / sqrt(sqrt(0.12769))) * 0.16134)
# 10          5.532e-03  7.092e-02  y = tanh(((exp(exp(x₀)) + x₀) + x₀) * 0.055617)
# 11          3.954e-03  3.358e-01  y = tanh((exp(exp(x₀)) + tanh(x₀ / 0.056905)) * 0.056905)
# 12          3.304e-03  1.796e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(inv(-0.99786) + x₀))))))
# 13          2.625e-03  2.300e-01  y = tanh(exp((x₀ + inv(tanh(inv(x₀ + -0.99786)))) - tanh(0.499...
#                                   9)))
# 14          2.363e-03  1.052e-01  y = tanh(exp((x₀ + inv(tanh(inv(x₀ + inv(-0.99786))))) - tanh(...
#                                   0.44348)))
# 15          1.969e-03  1.824e-01  y = tanh(exp((tanh(inv(-0.99786 + (x₀ * x₀))) - inv(exp(x₀))) ...
#                                   + x₀))
# 16          1.914e-03  2.856e-02  y = tanh(exp(x₀ + (tanh(inv(-0.99786 + x₀) / exp(x₀)) - inv(ex...
#                                   p(x₀)))))
# 17          1.411e-03  3.051e-01  y = tanh(exp((tanh(inv(-0.99786 + x₀) + (x₀ + x₀)) - inv(exp(x...
#                                   ₀))) + x₀))
# 18          6.089e-04  8.400e-01  y = tanh(exp((x₀ + (tanh(inv(x₀ + -0.99786)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - 0.48813))
# 19          4.208e-04  3.695e-01  y = tanh(exp((x₀ + (tanh(inv(x₀ + -0.99786)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(0.48813)))
# 20          3.991e-04  5.311e-02  y = tanh(exp((x₀ + (tanh(inv(tanh(x₀ + -0.99786))) - inv(exp(e...
#                                   xp(2.5778) * x₀)))) - sqrt(0.16015)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.680e+04
# Head worker occupation: 5.2%
# Progress: 896 / 5000 total iterations (17.920%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.349e-01  1.594e+01  y = -0.50643
# 2           4.774e-02  2.975e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 9           5.938e-03  1.792e-04  y = tanh(exp(x₀ / sqrt(sqrt(0.12769))) * 0.16134)
# 10          5.532e-03  7.092e-02  y = tanh(((exp(exp(x₀)) + x₀) + x₀) * 0.055617)
# 11          3.335e-03  5.059e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(x₀ + -0.99786))))))
# 12          2.470e-03  3.004e-01  y = tanh(exp((x₀ + inv(tanh(inv(-0.99786 + x₀)))) - 0.44348))
# 13          2.304e-03  6.948e-02  y = tanh(exp(x₀ + inv(tanh(tanh(inv(x₀ + -0.99786)) - -0.07426...
#                                   3))))
# 15          1.969e-03  7.857e-02  y = tanh(exp((tanh(inv(-0.99786 + (x₀ * x₀))) - inv(exp(x₀))) ...
#                                   + x₀))
# 16          1.914e-03  2.856e-02  y = tanh(exp(x₀ + (tanh(inv(-0.99786 + x₀) / exp(x₀)) - inv(ex...
#                                   p(x₀)))))
# 17          1.411e-03  3.051e-01  y = tanh(exp((tanh(inv(-0.99786 + x₀) + (x₀ + x₀)) - inv(exp(x...
#                                   ₀))) + x₀))
# 18          6.089e-04  8.400e-01  y = tanh(exp((x₀ + (tanh(inv(x₀ + -0.99786)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - 0.48813))
# 19          4.208e-04  3.695e-01  y = tanh(exp((x₀ + (tanh(inv(x₀ + -0.99786)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(0.48813)))
# 20          3.991e-04  5.311e-02  y = tanh(exp((x₀ + (tanh(inv(tanh(x₀ + -0.99786))) - inv(exp(e...
#                                   xp(2.5778) * x₀)))) - sqrt(0.16015)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.640e+04
# Head worker occupation: 5.0%
# Progress: 955 / 5000 total iterations (19.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.349e-01  1.594e+01  y = -0.50643
# 2           4.774e-02  2.975e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 9           5.938e-03  1.792e-04  y = tanh(exp(x₀ / sqrt(sqrt(0.12769))) * 0.16134)
# 10          5.509e-03  7.501e-02  y = tanh((exp(exp(x₀)) + (x₀ * 2.1577)) * 0.055617)
# 11          3.335e-03  5.018e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(x₀ + -0.99786))))))
# 12          2.470e-03  3.004e-01  y = tanh(exp((x₀ + inv(tanh(inv(-0.99786 + x₀)))) - 0.44348))
# 13          2.304e-03  6.948e-02  y = tanh(exp(x₀ + inv(tanh(tanh(inv(x₀ + -0.99786)) - -0.07426...
#                                   3))))
# 15          1.969e-03  7.857e-02  y = tanh(exp((tanh(inv(-0.99786 + (x₀ * x₀))) - inv(exp(x₀))) ...
#                                   + x₀))
# 16          1.688e-03  1.541e-01  y = tanh(exp((x₀ + inv(tanh(inv(x₀ + -0.99786) * exp(x₀)))) - ...
#                                   tanh(0.4999)))
# 17          1.411e-03  1.795e-01  y = tanh(exp((tanh(inv(-0.99786 + x₀) + (x₀ + x₀)) - inv(exp(x...
#                                   ₀))) + x₀))
# 18          6.089e-04  8.400e-01  y = tanh(exp((x₀ + (tanh(inv(x₀ + -0.99786)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - 0.48813))
# 19          3.739e-04  4.876e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(0.48813)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.620e+04
# Head worker occupation: 5.1%
# Progress: 1009 / 5000 total iterations (20.180%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.349e-01  1.594e+01  y = -0.50643
# 2           4.774e-02  2.975e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 9           5.938e-03  1.792e-04  y = tanh(exp(x₀ / sqrt(sqrt(0.12769))) * 0.16134)
# 10          5.509e-03  7.501e-02  y = tanh((exp(exp(x₀)) + (x₀ * 2.1577)) * 0.055617)
# 11          3.335e-03  5.018e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(x₀ + -0.99786))))))
# 12          2.470e-03  3.004e-01  y = tanh(exp((x₀ + inv(tanh(inv(-0.99786 + x₀)))) - 0.44348))
# 13          2.304e-03  6.948e-02  y = tanh(exp(x₀ + inv(tanh(tanh(inv(x₀ + -0.99786)) - -0.07426...
#                                   3))))
# 14          1.961e-03  1.615e-01  y = tanh(exp(tanh(x₀) + inv(tanh(tanh(inv(x₀ + -0.99786) + 0.2...
#                                   1364)))))
# 16          1.688e-03  7.489e-02  y = tanh(exp((x₀ + inv(tanh(inv(x₀ + -0.99786) * exp(x₀)))) - ...
#                                   tanh(0.4999)))
# 17          1.411e-03  1.795e-01  y = tanh(exp((tanh(inv(-0.99786 + x₀) + (x₀ + x₀)) - inv(exp(x...
#                                   ₀))) + x₀))
# 18          5.645e-04  9.159e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - 0.48813))
# 19          3.739e-04  4.118e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(0.48813)))
# 20          3.704e-04  9.667e-03  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(tanh(0.48813))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.610e+04
# Head worker occupation: 5.3%
# Progress: 1067 / 5000 total iterations (21.340%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.349e-01  1.594e+01  y = -0.50643
# 2           4.774e-02  2.975e+00  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 9           5.938e-03  1.792e-04  y = tanh(exp(x₀ / sqrt(sqrt(0.12769))) * 0.16134)
# 10          5.509e-03  7.501e-02  y = tanh((exp(exp(x₀)) + (x₀ * 2.1577)) * 0.055617)
# 11          3.268e-03  5.222e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-1.001 + x₀))))))
# 12          2.456e-03  2.857e-01  y = tanh(exp((inv(tanh(inv(-0.99883 + x₀))) + x₀) + -0.35036))
# 13          2.065e-03  1.733e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-0.99786 + x₀) - -0.3191))...
#                                   )))
# 14          1.709e-03  1.895e-01  y = tanh(exp(tanh(x₀) + inv(tanh(tanh(inv(-0.99786 + x₀) - -0....
#                                   3191)))))
# 16          1.515e-03  6.027e-02  y = tanh(exp(x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(tanh(x₀ ...
#                                   + x₀))))))
# 17          1.411e-03  7.110e-02  y = tanh(exp((tanh(inv(-0.99786 + x₀) + (x₀ + x₀)) - inv(exp(x...
#                                   ₀))) + x₀))
# 18          5.645e-04  9.159e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - 0.48813))
# 19          3.739e-04  4.118e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(0.48813)))
# 20          3.704e-04  9.667e-03  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(tanh(0.48813))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.570e+04
# Head worker occupation: 5.1%
# Progress: 1127 / 5000 total iterations (22.540%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.281e-01  1.594e+01  y = x₀
# 2           4.774e-02  9.872e-01  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 9           5.938e-03  1.792e-04  y = tanh(exp(x₀ / sqrt(sqrt(0.12769))) * 0.16134)
# 10          5.509e-03  7.501e-02  y = tanh((exp(exp(x₀)) + (x₀ * 2.1577)) * 0.055617)
# 11          3.268e-03  5.222e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-1.001 + x₀))))))
# 12          2.456e-03  2.857e-01  y = tanh(exp((inv(tanh(inv(-0.99883 + x₀))) + x₀) + -0.35036))
# 13          2.065e-03  1.733e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-0.99786 + x₀) - -0.3191))...
#                                   )))
# 14          1.709e-03  1.895e-01  y = tanh(exp(tanh(x₀) + inv(tanh(tanh(inv(-0.99786 + x₀) - -0....
#                                   3191)))))
# 16          1.515e-03  6.027e-02  y = tanh(exp(x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(tanh(x₀ ...
#                                   + x₀))))))
# 17          1.356e-03  1.107e-01  y = tanh(exp(x₀ + (tanh((inv(-0.99883 + x₀) + x₀) + x₀) - inv(...
#                                   exp(x₀)))))
# 18          5.645e-04  8.762e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - 0.48813))
# 19          3.739e-04  4.118e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(0.48813)))
# 20          3.704e-04  9.667e-03  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(tanh(0.48813))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.690e+04
# Head worker occupation: 5.0%
# Progress: 1195 / 5000 total iterations (23.900%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.281e-01  1.594e+01  y = x₀
# 2           4.774e-02  9.872e-01  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 9           5.938e-03  1.792e-04  y = tanh(exp(x₀ / sqrt(sqrt(0.12769))) * 0.16134)
# 10          5.509e-03  7.501e-02  y = tanh((exp(exp(x₀)) + (x₀ * 2.1577)) * 0.055617)
# 11          3.268e-03  5.222e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-1.001 + x₀))))))
# 12          2.456e-03  2.857e-01  y = tanh(exp((inv(tanh(inv(-0.99883 + x₀))) + x₀) + -0.35036))
# 13          2.065e-03  1.733e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-0.99786 + x₀) - -0.3191))...
#                                   )))
# 14          1.709e-03  1.895e-01  y = tanh(exp(tanh(x₀) + inv(tanh(tanh(inv(-0.99786 + x₀) - -0....
#                                   3191)))))
# 16          1.515e-03  6.027e-02  y = tanh(exp(x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(tanh(x₀ ...
#                                   + x₀))))))
# 17          1.356e-03  1.107e-01  y = tanh(exp(x₀ + (tanh((inv(-0.99883 + x₀) + x₀) + x₀) - inv(...
#                                   exp(x₀)))))
# 18          5.645e-04  8.762e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - 0.48813))
# 19          3.739e-04  4.118e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(0.48813)))
# 20          3.290e-04  1.280e-01  y = tanh(exp(((x₀ * 1.0616) + (tanh(inv(-0.99883 + x₀)) - inv(...
#                                   exp(exp(2.5778) * x₀)))) - 0.48813))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.640e+04
# Head worker occupation: 5.0%
# Progress: 1252 / 5000 total iterations (25.040%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.281e-01  1.594e+01  y = x₀
# 2           4.774e-02  9.872e-01  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# 9           5.938e-03  1.792e-04  y = tanh(exp(x₀ / sqrt(sqrt(0.12769))) * 0.16134)
# 10          5.509e-03  7.501e-02  y = tanh((exp(exp(x₀)) + (x₀ * 2.1577)) * 0.055617)
# 11          3.268e-03  5.222e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-1.001 + x₀))))))
# 12          2.456e-03  2.857e-01  y = tanh(exp((inv(tanh(inv(-0.99883 + x₀))) + x₀) + -0.35036))
# 13          2.065e-03  1.733e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-0.99786 + x₀) - -0.3191))...
#                                   )))
# 14          1.709e-03  1.895e-01  y = tanh(exp(tanh(x₀) + inv(tanh(tanh(inv(-0.99786 + x₀) - -0....
#                                   3191)))))
# 16          1.273e-03  1.471e-01  y = tanh(exp(x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(tanh(2.5...
#                                   778 * x₀))))))
# 18          5.645e-04  4.067e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - 0.48813))
# 19          3.739e-04  4.118e-01  y = tanh(exp((x₀ + (tanh(inv(-0.99883 + x₀)) - inv(exp(exp(2.5...
#                                   778) * x₀)))) - tanh(0.48813)))
# 20          3.290e-04  1.280e-01  y = tanh(exp(((x₀ * 1.0616) + (tanh(inv(-0.99883 + x₀)) - inv(...
#                                   exp(exp(2.5778) * x₀)))) - 0.48813))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.550e+04
# Head worker occupation: 4.9%
# Progress: 1304 / 5000 total iterations (26.080%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.281e-01  1.594e+01  y = x₀
# 2           4.774e-02  9.872e-01  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           2.022e-02  4.308e-01  y = exp(x₀) * 0.17666
# 5           9.387e-03  7.675e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(0.063222 * exp(exp(x₀)))
# 7           5.940e-03  1.641e-01  y = tanh(exp(x₀ / 0.59424) * 0.15961)
# ...
# 13          1.629e-03  4.110e-03  y = tanh((tanh(0.77849) + x₀) * exp(inv(tanh(inv(x₀ + -0.99999...
#                                   )))))
# 14          1.588e-03  2.541e-02  y = tanh(exp(inv(tanh(inv(x₀ + -0.99999) + 0.055782))) * (0.64...
#                                   257 + x₀))
# 15          1.228e-03  2.570e-01  y = tanh((0.64257 + x₀) * exp(inv(tanh(inv((-1 + x₀) / exp(x₀)...
#                                   )))))
# 16          1.154e-03  6.242e-02  y = tanh(exp(x₀ + (tanh(inv(x₀ + -0.99999)) - inv(exp(tanh(x₀ ...
#                                   / 0.29016))))))
# 17          4.746e-04  8.886e-01  y = tanh(sqrt((sqrt(x₀ * x₀) + x₀) * 1.2809) * exp(tanh(inv(x₀...
#                                    + -0.99883))))
# 18          3.822e-04  2.164e-01  y = tanh(exp(((tanh(inv(-1 + x₀)) - inv(exp(exp(2.5746) * x₀))...
#                                   ) + x₀) - 0.46283))
# 19          2.995e-04  2.441e-01  y = tanh(exp((x₀ + (tanh(tanh(inv(-1 + x₀))) - inv(exp(exp(2.6...
#                                   312) * x₀)))) - 0.67002))
# 20          2.769e-04  7.821e-02  y = tanh(exp(((tanh(inv(tanh(-1 + x₀))) - inv(exp(exp(2.6312) ...
#                                   * x₀))) + x₀) - tanh(0.46283)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.940e+04
# Head worker occupation: 4.3%
# Progress: 4715 / 5000 total iterations (94.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.461e-02  1.594e+01  y = 0.394
# 2           4.774e-02  5.723e-01  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           1.549e-02  6.976e-01  y = exp(x₀) * 0.20873
# 5           9.387e-03  5.007e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(exp(exp(x₀) - 2.7613))
# 7           5.940e-03  1.642e-01  y = tanh(0.15961 * exp(x₀ / 0.59383))
# 8           5.506e-03  7.594e-02  y = tanh(-1.1277 + sqrt(sqrt(exp(exp(x₀)))))
# 10          5.484e-03  1.999e-03  y = tanh((-1.1335 + exp(exp(x₀ - 1.319))) * 0.90749)
# 11          3.231e-03  5.289e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-1 + x₀))))))
# 12          1.636e-03  6.807e-01  y = tanh((0.64257 + x₀) * exp(inv(tanh(inv(x₀ + -0.99999)))))
# 13          1.629e-03  4.110e-03  y = tanh((tanh(0.77849) + x₀) * exp(inv(tanh(inv(x₀ + -0.99999...
#                                   )))))
# 14          1.588e-03  2.541e-02  y = tanh(exp(inv(tanh(inv(x₀ + -0.99999) + 0.055782))) * (0.64...
#                                   257 + x₀))
# 15          1.228e-03  2.570e-01  y = tanh((0.64257 + x₀) * exp(inv(tanh(inv((-1 + x₀) / exp(x₀)...
#                                   )))))
# 16          1.154e-03  6.242e-02  y = tanh(exp(x₀ + (tanh(inv(x₀ + -0.99999)) - inv(exp(tanh(x₀ ...
#                                   / 0.29016))))))
# 17          4.746e-04  8.886e-01  y = tanh(sqrt((sqrt(x₀ * x₀) + x₀) * 1.2809) * exp(tanh(inv(x₀...
#                                    + -0.99883))))
# 18          3.822e-04  2.164e-01  y = tanh(exp(((tanh(inv(-1 + x₀)) - inv(exp(exp(2.5746) * x₀))...
#                                   ) + x₀) - 0.46283))
# 19          2.995e-04  2.441e-01  y = tanh(exp((x₀ + (tanh(tanh(inv(-1 + x₀))) - inv(exp(exp(2.6...
#                                   312) * x₀)))) - 0.67002))
# 20          2.769e-04  7.821e-02  y = tanh(exp(((tanh(inv(tanh(-1 + x₀))) - inv(exp(exp(2.6312) ...
#                                   * x₀))) + x₀) - tanh(0.46283)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.070e+04
# Head worker occupation: 4.3%
# Progress: 4784 / 5000 total iterations (95.680%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.461e-02  1.594e+01  y = 0.394
# 2           4.774e-02  5.723e-01  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           1.549e-02  6.976e-01  y = exp(x₀) * 0.20873
# 5           9.387e-03  5.007e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(exp(exp(x₀) - 2.7613))
# 7           5.940e-03  1.642e-01  y = tanh(0.15961 * exp(x₀ / 0.59383))
# 8           5.506e-03  7.594e-02  y = tanh(-1.1277 + sqrt(sqrt(exp(exp(x₀)))))
# 10          5.484e-03  1.999e-03  y = tanh((-1.1335 + exp(exp(x₀ - 1.319))) * 0.90749)
# 11          3.231e-03  5.289e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-1 + x₀))))))
# 12          1.636e-03  6.807e-01  y = tanh((0.64257 + x₀) * exp(inv(tanh(inv(x₀ + -0.99999)))))
# 13          1.629e-03  4.110e-03  y = tanh((tanh(0.77849) + x₀) * exp(inv(tanh(inv(x₀ + -0.99999...
#                                   )))))
# 14          1.588e-03  2.541e-02  y = tanh(exp(inv(tanh(inv(x₀ + -0.99999) + 0.055782))) * (0.64...
#                                   257 + x₀))
# 15          1.228e-03  2.570e-01  y = tanh((0.64257 + x₀) * exp(inv(tanh(inv((-1 + x₀) / exp(x₀)...
#                                   )))))
# 16          1.154e-03  6.242e-02  y = tanh(exp(x₀ + (tanh(inv(x₀ + -0.99999)) - inv(exp(tanh(x₀ ...
#                                   / 0.29016))))))
# 17          4.746e-04  8.886e-01  y = tanh(sqrt((sqrt(x₀ * x₀) + x₀) * 1.2809) * exp(tanh(inv(x₀...
#                                    + -0.99883))))
# 18          3.822e-04  2.164e-01  y = tanh(exp(((tanh(inv(-1 + x₀)) - inv(exp(exp(2.5746) * x₀))...
#                                   ) + x₀) - 0.46283))
# 19          2.995e-04  2.441e-01  y = tanh(exp((x₀ + (tanh(tanh(inv(-1 + x₀))) - inv(exp(exp(2.6...
#                                   312) * x₀)))) - 0.67002))
# 20          2.769e-04  7.821e-02  y = tanh(exp(((tanh(inv(tanh(-1 + x₀))) - inv(exp(exp(2.6312) ...
#                                   * x₀))) + x₀) - tanh(0.46283)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.010e+04
# Head worker occupation: 4.3%
# Progress: 4851 / 5000 total iterations (97.020%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.461e-02  1.594e+01  y = 0.394
# 2           4.774e-02  5.723e-01  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           1.549e-02  6.976e-01  y = exp(x₀) * 0.20873
# 5           9.387e-03  5.007e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(exp(exp(x₀) - 2.7613))
# 7           5.940e-03  1.642e-01  y = tanh(0.15961 * exp(x₀ / 0.59383))
# 8           5.506e-03  7.594e-02  y = tanh(-1.1277 + sqrt(sqrt(exp(exp(x₀)))))
# 10          5.484e-03  1.999e-03  y = tanh((-1.1335 + exp(exp(x₀ - 1.319))) * 0.90749)
# 11          3.231e-03  5.289e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-1 + x₀))))))
# 12          1.636e-03  6.807e-01  y = tanh((0.64257 + x₀) * exp(inv(tanh(inv(x₀ + -0.99999)))))
# 13          1.629e-03  4.110e-03  y = tanh((tanh(0.77849) + x₀) * exp(inv(tanh(inv(x₀ + -0.99999...
#                                   )))))
# 14          1.588e-03  2.541e-02  y = tanh(exp(inv(tanh(inv(x₀ + -0.99999) + 0.055782))) * (0.64...
#                                   257 + x₀))
# 15          1.228e-03  2.570e-01  y = tanh((0.64257 + x₀) * exp(inv(tanh(inv((-1 + x₀) / exp(x₀)...
#                                   )))))
# 16          1.154e-03  6.242e-02  y = tanh(exp(x₀ + (tanh(inv(x₀ + -0.99999)) - inv(exp(tanh(x₀ ...
#                                   / 0.29016))))))
# 17          4.746e-04  8.886e-01  y = tanh(sqrt((sqrt(x₀ * x₀) + x₀) * 1.2809) * exp(tanh(inv(x₀...
#                                    + -0.99883))))
# 18          3.822e-04  2.164e-01  y = tanh(exp(((tanh(inv(-1 + x₀)) - inv(exp(exp(2.5746) * x₀))...
#                                   ) + x₀) - 0.46283))
# 19          2.995e-04  2.441e-01  y = tanh(exp((x₀ + (tanh(tanh(inv(-1 + x₀))) - inv(exp(exp(2.6...
#                                   312) * x₀)))) - 0.67002))
# 20          2.769e-04  7.821e-02  y = tanh(exp(((tanh(inv(tanh(-1 + x₀))) - inv(exp(exp(2.6312) ...
#                                   * x₀))) + x₀) - tanh(0.46283)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.950e+04
# Head worker occupation: 4.3%
# Progress: 4914 / 5000 total iterations (98.280%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.461e-02  1.594e+01  y = 0.394
# 2           4.774e-02  5.723e-01  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           1.549e-02  6.976e-01  y = exp(x₀) * 0.20873
# 5           9.387e-03  5.007e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(exp(exp(x₀) - 2.7613))
# 7           5.940e-03  1.642e-01  y = tanh(0.15961 * exp(x₀ / 0.59383))
# 8           5.506e-03  7.594e-02  y = tanh(-1.1277 + sqrt(sqrt(exp(exp(x₀)))))
# 10          5.484e-03  1.999e-03  y = tanh((-1.1335 + exp(exp(x₀ - 1.319))) * 0.90749)
# 11          3.231e-03  5.289e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-1 + x₀))))))
# 12          1.630e-03  6.846e-01  y = tanh((0.6502 + x₀) * exp(inv(tanh(inv(-0.99999 + x₀)))))
# 13          1.622e-03  4.495e-03  y = tanh((0.64257 + x₀) * exp(0.99461 / tanh(inv(-1 + x₀))))
# 14          1.588e-03  2.115e-02  y = tanh(exp(inv(tanh(inv(x₀ + -0.99999) + 0.055782))) * (0.64...
#                                   257 + x₀))
# 15          1.228e-03  2.570e-01  y = tanh((0.64257 + x₀) * exp(inv(tanh(inv((-1 + x₀) / exp(x₀)...
#                                   )))))
# 16          1.154e-03  6.242e-02  y = tanh(exp(x₀ + (tanh(inv(x₀ + -0.99999)) - inv(exp(tanh(x₀ ...
#                                   / 0.29016))))))
# 17          4.746e-04  8.886e-01  y = tanh(sqrt((sqrt(x₀ * x₀) + x₀) * 1.2809) * exp(tanh(inv(x₀...
#                                    + -0.99883))))
# 18          3.613e-04  2.727e-01  y = tanh(exp(((tanh(inv(-1 + x₀)) - inv(exp(exp(2.6312) * x₀))...
#                                   ) + x₀) - 0.4238))
# 19          2.995e-04  1.877e-01  y = tanh(exp((x₀ + (tanh(tanh(inv(-1 + x₀))) - inv(exp(exp(2.6...
#                                   312) * x₀)))) - 0.67002))
# 20          2.769e-04  7.821e-02  y = tanh(exp(((tanh(inv(tanh(-1 + x₀))) - inv(exp(exp(2.6312) ...
#                                   * x₀))) + x₀) - tanh(0.46283)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.830e+04
# Head worker occupation: 4.3%
# Progress: 4981 / 5000 total iterations (99.620%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.461e-02  1.594e+01  y = 0.394
# 2           4.774e-02  5.723e-01  y = tanh(x₀)
# 3           3.111e-02  4.281e-01  y = 0.60419 * x₀
# 4           1.549e-02  6.976e-01  y = exp(x₀) * 0.20873
# 5           9.387e-03  5.007e-01  y = 0.45001 * (x₀ + 0.42422)
# 6           7.000e-03  2.934e-01  y = tanh(exp(exp(x₀) - 2.7613))
# 7           5.940e-03  1.642e-01  y = tanh(0.15961 * exp(x₀ / 0.59383))
# 8           5.506e-03  7.594e-02  y = tanh(-1.1277 + sqrt(sqrt(exp(exp(x₀)))))
# 10          5.484e-03  1.999e-03  y = tanh((-1.1335 + exp(exp(x₀ - 1.319))) * 0.90749)
# 11          3.231e-03  5.289e-01  y = tanh(exp(x₀ + inv(tanh(tanh(inv(-1 + x₀))))))
# 12          1.630e-03  6.846e-01  y = tanh((0.6502 + x₀) * exp(inv(tanh(inv(-0.99999 + x₀)))))
# 13          1.622e-03  4.495e-03  y = tanh((0.64257 + x₀) * exp(0.99461 / tanh(inv(-1 + x₀))))
# 14          1.228e-03  2.781e-01  y = tanh((0.64257 + x₀) * exp(inv(tanh(exp(x₀) / (-1 + x₀)))))
# 16          1.079e-03  6.483e-02  y = tanh((0.64257 + x₀) * exp(inv(tanh(exp(x₀ + x₀) / (-1 + x₀...
#                                   )))))
# 17          4.746e-04  8.214e-01  y = tanh(sqrt((sqrt(x₀ * x₀) + x₀) * 1.2809) * exp(tanh(inv(x₀...
#                                    + -0.99883))))
# 18          3.613e-04  2.727e-01  y = tanh(exp(((tanh(inv(-1 + x₀)) - inv(exp(exp(2.6312) * x₀))...
#                                   ) + x₀) - 0.4238))
# 19          2.995e-04  1.877e-01  y = tanh(exp((x₀ + (tanh(tanh(inv(-1 + x₀))) - inv(exp(exp(2.6...
#                                   312) * x₀)))) - 0.67002))
# 20          2.769e-04  7.821e-02  y = tanh(exp(((tanh(inv(tanh(-1 + x₀))) - inv(exp(exp(2.6312) ...
#                                   * x₀))) + x₀) - tanh(0.46283)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                         0.39400098
# 	1         0.572316                                           tanh(x0)
# 	2         0.428131                                    0.60418624 * x0
# 	3         0.697582                                  exp(x0) * 0.20873
# 	4         0.500719                      0.4500078 * (x0 + 0.42421827)
# 	5         0.293395                     tanh(exp(exp(x0) - 2.7612722))
# 	6         0.164202             tanh(0.15961422 * exp(x0 / 0.5938308))
# 	7         0.075940         tanh(-1.127704 + sqrt(sqrt(exp(exp(x0)))))
# 	8         0.001999  tanh((-1.1334844 + exp(exp(x0 - 1.3189734))) *...
# 	9         0.528905  tanh(exp(x0 + inv(tanh(tanh(inv(-0.9999995 + x...
# 	10        0.684554  tanh((0.6501973 + x0) * exp(inv(tanh(inv(-0.99...
# 	11        0.004495  tanh((0.64257365 + x0) * exp(0.9946129 / tanh(...
# 	12        0.278142  tanh((0.64257365 + x0) * exp(inv(tanh(exp(x0) ...
# 	13        0.064825  tanh((0.64257365 + x0) * exp(inv(tanh(exp(x0 +...
# 	14        0.821363  tanh(sqrt((sqrt(x0 * x0) + x0) * 1.2809308) * ...
# 	15        0.272721  tanh(exp(((tanh(inv(-0.9999995 + x0)) - inv(ex...
# 	16  >>>>  0.285386  tanh(exp(((tanh(inv(tanh(-0.9999995 + x0))) - ...
#
# 	        loss  complexity
# 	0   0.084610           1
# 	1   0.047738           2
# 	2   0.031112           3
# 	3   0.015487           4
# 	4   0.009387           5
# 	5   0.007000           6
# 	6   0.005940           7
# 	7   0.005506           8
# 	8   0.005484          10
# 	9   0.003231          11
# 	10  0.001630          12
# 	11  0.001622          13
# 	12  0.001228          14
# 	13  0.001079          16
# 	14  0.000475          17
# 	15  0.000361          18
# 	16  0.000272          19
# ]

# %%
pysr_model.sympy()
# Out:
# tanh(1/(1.1812416*sqrt(x0) + 1.29124678757377*sqrt(-x0 + 1/x0)))

# %%
expr = psyr_model.sympy()

import sympy as sp

x0 = sp.Symbol('x0')
y = sp.Symbol('y')

inverted_expr = sp.solve(sp.Eq(expr, y), x0)

# %%
from autora.theorist.bms import BMSRegressor

temperatures = [1.0] + [1.04**k for k in range(1, 20)]

bms_estimator = BMSRegressor(
    epochs=1000,
    ts=temperatures,
)

x = df.right_borders.values[:, None]
y = np.cumsum(df.probs).values

bms_estimator.fit(x_padded,y_padded)
# Out:
# INFO:autora.theorist.bms.regressor:BMS fitting started
# 100%|██████████| 1000/1000 [02:28<00:00,  6.75it/s]
# INFO:autora.theorist.bms.regressor:BMS fitting finished
# sig(((((X0 ** 3) ** 3) ** 3) + (((((X0 + -0.64) + -0.64) + X0) ** 3) + (-0.64 ** 3))))

# %%
x = df.right_borders.values[:, None]
y = np.cumsum(df.probs).values
plt.plot(x,y, label = "learned")

y_pred = pysr_model.predict(x)
plt.plot(x,y_pred, label = "psyr")

# y_pred = pysr_model_padded.predict(x)
# plt.plot(x,y_pred, label = "psyr padded")

# y_pred = bms_estimator.predict(x)
# plt.plot(x,y_pred, label = "bms")



plt.legend()
plt.show()
