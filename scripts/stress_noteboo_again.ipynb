# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sam import *
from sam.system_stress import CleanedPred, predict_with_hormesis_cancelled

# %%
data = read_data("/Users/felix/Desktop/sam/data/2019 Naeem-Esf, Pro, food/21_days.xlsx")
ser = data.additional_stress["Food_1% + Prochloraz_100"]

sam_prediction(
    main_series=data.main_series,
    stressor_series=ser,
    meta=data.meta,
).plot()
plt.show()

predict_with_hormesis_cancelled(
    main_series=data.main_series,
    stressor_series=ser,
    additional_stress=0.18,
    hormesis_index=3,
    meta=data.meta,
).plot()
plt.show()

# %%
data = read_data("/Users/felix/Desktop/sam/data/2001 Liess-food, UV Cu/data.xlsx")

ser = data.additional_stress["Food_1% + UV"]

sam_prediction(
    main_series=data.main_series,
    stressor_series=ser,
    meta=data.meta,
).plot()
plt.show()

predict_with_hormesis_cancelled(
    main_series=data.main_series,
    stressor_series=ser,
    additional_stress=0.18,
    hormesis_index=3,
    meta=data.meta,
).plot()
plt.show()

# %%
data = read_data("/Users/felix/Desktop/sam/data/2024 Naeem-Mix13,°C,food/21_days.xlsx")

ser = data.additional_stress["Temp_25 + Food_1%"]

sam_prediction(
    main_series=data.main_series,
    stressor_series=ser,
    meta=data.meta,
).plot()
plt.show()

predict_with_hormesis_cancelled(
    main_series=data.main_series,
    stressor_series=ser,
    additional_stress=0.18,
    hormesis_index=4,
    meta=data.meta,
).plot()
plt.show()

# %%
data = read_data("/Users/felix/Desktop/sam/data/2024 Naeem-Esfe, °C, food/21_days.xlsx")

ser = data.additional_stress["Food_1% + Temp_25"]

sam_prediction(
    main_series=data.main_series,
    stressor_series=ser,
    meta=data.meta,
).plot()
plt.show()

predict_with_hormesis_cancelled(
    main_series=data.main_series,
    stressor_series=ser,
    additional_stress=0.18,
    hormesis_index=4,
    meta=data.meta,
).plot()
plt.show()
